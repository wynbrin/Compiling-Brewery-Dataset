# %% [markdown]
# # Creating a Dataset of Brewery Data via Google Places API
#
# ###The DSCI 511 Brewery Team:
# Wynton Britton
#
# Russell Destremps
#
# Hao Deng
#
# Evan Falkowski
#
# DSCI 511, Data Acquisition and Pre-Processing

# %% [markdown]
# # Pre-Processing

# %%
import pandas as pd

#The master list of breweries compiled off of the national registry of breweries
with open('/content/drive/MyDrive/DCSI Colab Directory/Copy of brewery_master.csv', 'r') as master:

  brewdata = pd.read_csv(master)
  brewtable = pd.DataFrame(brewdata)

# %%
print(str(brewtable.iloc[0]['latitude']) + ' ' + str(brewtable.iloc[0]['longitude']))
# Out:
# 47.822407 -122.87535600000001

# %%
brewtable.iloc[0]['region']
# Out:
# 'WA'

# %%
brewtable.head()
# Out:
#       type        location_name region   latitude   longitude
# 0  Brewpub          101 Brewery     WA  47.822407 -122.875356
# 1  Brewpub  122 West Brewing Co     WA  48.762557 -122.485773
# 2  Brewpub     12Degree Brewing     CO  39.978215 -105.131876
# 3  Brewpub     15 24 Brew House     KS  39.376021  -97.127491
# 4  Brewpub     16 Stone Brewpub     NY  43.241849  -75.256302

# %% [markdown]
# Using the location_name column from the master list as a base, we made requests to the Google Places API. The general structure of the Google Places json data type is html_attributions (empty list), results (list of dictionaries/actual results of the search) and status (OK, ZERO_RESULTS)

# %%
import requests, json 
diction = dict()
# enter your api key here 
api_key = 'Your API key'
  
# url variable store url 
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"

for each in range(len(brewtable)):
  # goes through each row and pulls the name and type of each brewery in the dataframe
  query = str(brewtable.iloc[each]['location_name']) + ', ' + str(brewtable.iloc[each]['type'])
    
  #returns the json formatted search query
  r = requests.get(url + 'query=' + query +
                          '&key=' + api_key) 
  

    
  #creates a new dictionary of length 8000, keys being the names as recorded on the master list and
  #their associated values being the results from that specific query. 
  diction[str(brewtable.iloc[each]['location_name'])] = json.loads(r.text)

# %%
#writes out a copy of the dictionary in a .json file for later use
#and to preserve the data

with open('/content/drive/MyDrive/DCSI Colab Directory/google_queries2.json', 'w') as f:
  json.dump(diction, f)

# %%
newkeys = list()

for each in brewtable['location_name']:

  newkeys.append(each)

len(newkeys)
# Out:
# 8000

# %% [markdown]
# ## Experimentation

# %% [markdown]
# The following code provides an example of further exploration into the data, and my process in formulating a strategy to further clean it.

# %%
search = dict()
# Out:
# {'business_status': 'OPERATIONAL', 'formatted_address': '3301 Southern Blvd SE, Rio Rancho, NM 87124, United States', 'geometry': {'location': {'lat': 35.2432541, 'lng': -106.6693816}, 'viewport': {'northeast': {'lat': 35.24450147989273, 'lng': -106.6680585701073}, 'southwest': {'lat': 35.24180182010728, 'lng': -106.6707582298927}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png', 'name': 'Brew Lab 101 Beer & Cider Co.', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3456, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104955109889669340743">Scott Gorsky</a>'], 'photo_reference': 'ATtYBwKHoLxrRwj1duNXdOJa1OMjKBZ4KBfM9HiHlr5Nc9qa9Ivc-3Qj5Fw5sLoqbRnsbZDULx6KPlN5i2U0bd_3sUcnVxvMELKu7onwPLzA9sc2DZnI6Mlje8oas8-oqgry2KSisr2CHEttUaFvVnVDmmMOMGZ6zSGsX3n720ypGbH4pU9c', 'width': 4608}], 'place_id': 'ChIJI4Mf7-BxIocRFBhfwOJIoAk', 'plus_code': {'compound_code': '68VJ+86 Rio Rancho, New Mexico', 'global_code': '857M68VJ+86'}, 'rating': 4.8, 'reference': 'ChIJI4Mf7-BxIocRFBhfwOJIoAk', 'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'], 'user_ratings_total': 86}
# {'business_status': 'OPERATIONAL', 'formatted_address': '2416 Meridian St, Bellingham, WA 98225, United States', 'geometry': {'location': {'lat': 48.7625675, 'lng': -122.4858342}, 'viewport': {'northeast': {'lat': 48.76391782989273, 'lng': -122.4846295701073}, 'southwest': {'lat': 48.76121817010728, 'lng': -122.4873292298928}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png', 'name': '122 West Brewing Co.', 'opening_hours': {'open_now': False}, 'photos': [{'height': 1440, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115258052358653244868">A Google User</a>'], 'photo_reference': 'ATtYBwJdUKmgc22OexBs_uRipT4p3eM5BnbfLIYjiCo8xYTiGsd6l-gveAjj5CJhLv6IKRSl_uapfEj9MTvdVGIu84ZvO98sXHkRsDVJOZ4hD4gj07CRnVKQnP4Cf6syKOI3ems7dvTV5iUUPAJx_SsT9aqPJXL-hzKLvxXS3EWDNTUb1WQ4', 'width': 1440}], 'place_id': 'ChIJU24foIijhVQRt25PZ8UrOBk', 'plus_code': {'compound_code': 'QG77+2M Bellingham, Washington', 'global_code': '84WVQG77+2M'}, 'rating': 4.6, 'reference': 'ChIJU24foIijhVQRt25PZ8UrOBk', 'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'], 'user_ratings_total': 61}
# {'business_status': 'OPERATIONAL', 'formatted_address': '820 Main St, Louisville, CO 80027, United States', 'geometry': {'location': {'lat': 39.9782385, 'lng': -105.1319916}, 'viewport': {'northeast': {'lat': 39.97958907989272, 'lng': -105.1307101201073}, 'southwest': {'lat': 39.97688942010728, 'lng': -105.1334097798927}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png', 'name': '12Degree Brewing', 'opening_hours': {'open_now': True}, 'photos': [{'height': 2237, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102700741848758923705">Twelve Degree Brewing</a>'], 'photo_reference': 'ATtYBwLRYNYwuLa1JJvHdA4jWgQzLe9hkfuLsTrR8yUx3wSt2u2dx9xddITDRY67TlNZ1-2Jwgo4gam_8zpddkwB5GNak4c-XyrA-fVni9GN8Fm0gKy-qQivmHBmWHL7sbmSYoUwIt1ftSiFCYVuFZI4FynhGjrYzPOvsunY_aEzULMTVAzL', 'width': 2237}], 'place_id': 'ChIJV5-01V3za4cRHErorPGilxs', 'plus_code': {'compound_code': 'XVH9+76 Louisville, Colorado', 'global_code': '85FPXVH9+76'}, 'price_level': 2, 'rating': 4.7, 'reference': 'ChIJV5-01V3za4cRHErorPGilxs', 'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'], 'user_ratings_total': 231}
# {'business_status': 'OPERATIONAL', 'formatted_address': '420 Lincoln Ave, Clay Center, KS 67432, United States', 'geometry': {'location': {'lat': 39.3761435, 'lng': -97.1275175}, 'viewport': {'northeast': {'lat': 39.37755837989272, 'lng': -97.12616702010729}, 'southwest': {'lat': 39.37485872010727, 'lng': -97.12886667989272}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png', 'name': '15-24 Brew House', 'opening_hours': {'open_now': False}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102794122164029792267">Morgan Sharp</a>'], 'photo_reference': 'ATtYBwK6qGysxncYKGRKSN6Kt4thSpP_w6imKbQ5jGDMf890WwEW38sc2tvu8PLneMuQAVO5zOfVwW0R26fFJP90Kk44HwXh2C_mwwpBLSYhplDGF8u-b-TsrjYHhwldy8Wh_JKUOMIcxgpQbfkh0--IPwnInewpSCixRUhBPfiAav9lN-Vr', 'width': 4032}], 'place_id': 'ChIJx9ohZWcLvYcR1aoQkLFrd8g', 'plus_code': {'compound_code': '9VGC+FX Clay Center, Kansas', 'global_code': '86F49VGC+FX'}, 'rating': 4.6, 'reference': 'ChIJx9ohZWcLvYcR1aoQkLFrd8g', 'types': ['restaurant', 'food', 'point_of_interest', 'establishment'], 'user_ratings_total': 130}
# {'business_status': 'OPERATIONAL', 'formatted_address': '9542 Main St, Holland Patent, NY 13354, United States', 'geometry': {'location': {'lat': 43.2418785, 'lng': -75.25634}, 'viewport': {'northeast': {'lat': 43.24330112989272, 'lng': -75.25506852010727}, 'southwest': {'lat': 43.24060147010728, 'lng': -75.25776817989271}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png', 'name': '16 Stone Brewpub', 'opening_hours': {'open_now': True}, 'photos': [{'height': 1536, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108049004380651177051">A Google User</a>'], 'photo_reference': 'ATtYBwK8YlobCDOd7yVCxZAHYpSG1hWcD6deSJ-ffN4ECD39crfuXFx3gVggVaV5Lci10_Tbamb2u0OMzJb9R-ezd71s1XrvrgCt35z04PM-oMLarZu0REAyhrn_0Ty-sTFldU-KxI8N053PGJAwfNi4vEJPvRRIpEGdlChFMj0AE-zHuwgb', 'width': 2048}], 'place_id': 'ChIJ8Rn1hnA82YkRpnCWF83_Gww', 'plus_code': {'compound_code': '6PRV+QF Holland Patent, New York', 'global_code': '87M66PRV+QF'}, 'rating': 4.6, 'reference': 'ChIJ8Rn1hnA82YkRpnCWF83_Gww', 'types': ['bar', 'food', 'point_of_interest', 'establishment'], 'user_ratings_total': 71}
# {'business_status': 'OPERATIONAL', 'formatted_address': '1129 Irvin Garrish Hwy, Ocracoke, NC 27960, United States', 'geometry': {'location': {'lat': 35.107474, 'lng': -75.971818}, 'viewport': {'northeast': {'lat': 35.10865152989272, 'lng': -75.97054437010728}, 'southwest': {'lat': 35.10595187010728, 'lng': -75.97324402989273}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png', 'name': '1718 Brewing Ocracoke', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103873422033864105645">A Google User</a>'], 'photo_reference': 'ATtYBwLMxrauScshOzAUuvjBptf77QOab6Kx0cXiRPfrjnPW09QO9txDRYii4sMj_grsE1wmRtbKGH2Faqz2nBmj7j26STrxqARVp9D8UCJPjWtBczBNOJouB-27MFW8tScluRcaNZeeAsmQBQCaV2P6B5UHnTC0VK68SIJGiBiyd2bkvXKY', 'width': 4032}], 'place_id': 'ChIJXcSUGb3YpYkRU1HgPbZ5l8I', 'plus_code': {'compound_code': '424H+X7 Ocracoke, North Carolina', 'global_code': '8776424H+X7'}, 'rating': 4.7, 'reference': 'ChIJXcSUGb3YpYkRU1HgPbZ5l8I', 'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'], 'user_ratings_total': 213}
# {'business_status': 'OPERATIONAL', 'formatted_address': '43 S Fourth St, Hamburg, PA 19526, United States', 'geometry': {'location': {'lat': 40.554327, 'lng': -75.98189099999999}, 'viewport': {'northeast': {'lat': 40.55566147989272, 'lng': -75.98060627010727}, 'southwest': {'lat': 40.55296182010728, 'lng': -75.98330592989271}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png', 'name': '1787 Brewing Company', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113035195714389391764">Dana Foust</a>'], 'photo_reference': 'ATtYBwJy8_hxgn8DLKFX2L7Z7zhQuW_5uZ_jAbqFeOAb-miHlXmIKSF97JG_ckM9ZcwIFrHbC7Xq7gL0N2sFI1pGNcuNkd-UL4jWONQU8C0YFj9sGb7gkiVYZUCKfSTSiXLJZmiMTu5TiLODWfjz5D13j6HTsjO4TsqtCUOixU8o5rkHED2e', 'width': 4032}], 'place_id': 'ChIJm-iMT2XbxYkRBa8yUr2NCPM', 'plus_code': {'compound_code': 'H239+P6 Hamburg, Pennsylvania', 'global_code': '87G6H239+P6'}, 'price_level': 2, 'rating': 4.5, 'reference': 'ChIJm-iMT2XbxYkRBa8yUr2NCPM', 'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'], 'user_ratings_total': 518}
# {'business_status': 'OPERATIONAL', 'formatted_address': '468 Sutton Way, Grass Valley, CA 95945, United States', 'geometry': {'location': {'lat': 39.2324126, 'lng': -121.0368826}, 'viewport': {'northeast': {'lat': 39.23382222989272, 'lng': -121.0351654201073}, 'southwest': {'lat': 39.23112257010728, 'lng': -121.0378650798927}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png', 'name': '1849 Brewing Company', 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104449113900710011219">Matt O</a>'], 'photo_reference': 'ATtYBwKgPrwPr44kpiPADFG7dM4y6mll5jCfucra8tc8k8w8Ji_89GXZUHW_ATLppO4I8Own_M3KHifl6xTfCH4Y_oL2SREM5qxZY_ARcylC_JCrXscp6Muul54si3oZ_URbgTLudUhqbSoKJMN1Je2hA1i3jFqqOK4AwDHZ_WlSyElYH7Y-', 'width': 4032}], 'place_id': 'ChIJoUtya1Bxm4ARGG8BoeoOHEE', 'plus_code': {'compound_code': '6XJ7+X6 Grass Valley, California', 'global_code': '84FW6XJ7+X6'}, 'rating': 3.9, 'reference': 'ChIJoUtya1Bxm4ARGG8BoeoOHEE', 'types': ['food', 'point_of_interest', 'establishment'], 'user_ratings_total': 131}
# {'business_status': 'OPERATIONAL', 'formatted_address': '300 Richardson St, Brooklyn, NY 11222, United States', 'geometry': {'location': {'lat': 40.7195918, 'lng': -73.93958219999999}, 'viewport': {'northeast': {'lat': 40.72099027989272, 'lng': -73.93825847010727}, 'southwest': {'lat': 40.71829062010728, 'lng': -73.9409581298927}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png', 'name': '18th Ward Brewing', 'opening_hours': {'open_now': True}, 'photos': [{'height': 640, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113955271760348556882">A Google User</a>'], 'photo_reference': 'ATtYBwLmFsz6PrvY7WUNhXaVVpAeBAZJKNtGqMikewgGa43x5dPRO_RD5V_YDQfcaBoVBP2-A3FmdC4M-kiyU5EEIiarBhnb4_VqThFwiacN1_elWuf-zScNTRW2VljVR2Hdq9hbtmk4UdqdYnDAQ30Ow_dZ-lYkDIXl60Viubgy99459o50', 'width': 480}], 'place_id': 'ChIJAWcAJyJZwokRLVQFkjOVMKg', 'plus_code': {'compound_code': 'P396+R5 Brooklyn, New York', 'global_code': '87G8P396+R5'}, 'rating': 4.5, 'reference': 'ChIJAWcAJyJZwokRLVQFkjOVMKg', 'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'], 'user_ratings_total': 37}
# {'business_status': 'OPERATIONAL', 'formatted_address': '80 Columbia St, Bangor, ME 04401, United States', 'geometry': {'location': {'lat': 44.8002365, 'lng': -68.7727324}, 'viewport': {'northeast': {'lat': 44.80161157989273, 'lng': -68.77146532010728}, 'southwest': {'lat': 44.79891192010728, 'lng': -68.77416497989273}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png', 'name': '2 Feet Brewing Co.', 'opening_hours': {'open_now': True}, 'photos': [{'height': 2340, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102764704132906514142">2 Feet Brewing Co.</a>'], 'photo_reference': 'ATtYBwK-o80dS6-xqZ6PydP0sGpLZUj1HApnseyuqR0ter8wmW2rbmUBqYTcP_haS-r9VXC4-DS893eopytxl5N8z8JcsfCF1QEp8Y9qqGe0_GvIBHa8pr4V8tkys6HGU1Zi1fv1BEv69eUr00JxXTK669_DdurM5xe0gd92Pgo2Ej-buKKm', 'width': 4160}], 'place_id': 'ChIJx4BBvkRLrkwR2Dp4_FtNTsA', 'plus_code': {'compound_code': 'R62G+3W Bangor, Maine', 'global_code': '87PHR62G+3W'}, 'price_level': 1, 'rating': 4.6, 'reference': 'ChIJx4BBvkRLrkwR2Dp4_FtNTsA', 'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'], 'user_ratings_total': 211}

# %%
newrecord['10 56 Brewing Company']['results']
# Out:
# [{'business_status': 'OPERATIONAL',
#   'formatted_address': '2120 US-35, Knox, IN 46534, United States',
#   'geometry': {'location': {'lat': 41.2714471, 'lng': -86.6198986},
#    'viewport': {'northeast': {'lat': 41.27279852989272,
#      'lng': -86.61892352010727},
#     'southwest': {'lat': 41.27009887010728, 'lng': -86.62162317989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': '10-56 Brewing Company',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1960,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116394161315309694627">Brian Ballas</a>'],
#     'photo_reference': 'ATtYBwL9xEcGUZxpE87Dey2fy7-j5RZ4dQyTb_N2X6XyyzgRNuwOBRmyKcoFvzL_IJEjHXZMNyXrz3w2B7hvU83oSFomaY4MKW7ot4aaGMHmKqZqzOcq6Uve-Tz3bOheJbpJFL3lKpwY5nYCDNlLM8Maz9yIMo8wq9wI5QDJjSYTrucA4fFD',
#     'width': 4032}],
#   'place_id': 'ChIJJe0v3FthEYgR94PwUjG8gOI',
#   'plus_code': {'compound_code': '79CJ+H2 Knox, Indiana',
#    'global_code': '86HM79CJ+H2'},
#   'rating': 4.9,
#   'reference': 'ChIJJe0v3FthEYgR94PwUjG8gOI',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 48}]

# %%
names = list()
address = list()
coord = list()
rating = list()
total_reviews = list()
results = list()


for each in newrecord:
  rec = newrecord[each]
  
  for key in rec:
    if key == 'results':
      results.append(rec[key])

# %%
results2 = list()
i = 1
for each in results:
  for element in each:
    results2.append(element)

# %%
results = results2

# %%
for each in newrecord:
  names.append(each)

# %%
search = dict()

for each in results:
  if each['name'] in names:
    search[each['name']] = each

# %%
len(search)
# Out:
# 3424

# %%
search
# Out:
# {'602 Brewing Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '919 Main St, Bastrop, TX 78602, United States',
#   'geometry': {'location': {'lat': 30.1099225, 'lng': -97.31987540000002},
#    'viewport': {'northeast': {'lat': 30.11127117989273,
#      'lng': -97.31857872010728},
#     'southwest': {'lat': 30.10857152010728, 'lng': -97.32127837989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': '602 Brewing Company',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 540,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117735802277423726269">A Google User</a>'],
#     'photo_reference': 'ATtYBwJiuRO6qHdzKkDhJYd9kkWbh25WUEljYYUcyu7R7XO0CmFH4LaG6yVnpAFGtOqD9EMUy4S0InujPyc1yrlkkPwumhB-Nxw4PINjy8dvZ6nsUedJQsLLypFM-Sakca7zTDQVy1BCsomXAnEMic9nUGITUAIc7YIofszG1HaoOOxOVlkR',
#     'width': 720}],
#   'place_id': 'ChIJkXGesUSaRIYRYuTWrq7szQ0',
#   'plus_code': {'compound_code': '4M5J+X2 Bastrop, Texas',
#    'global_code': '86244M5J+X2'},
#   'price_level': 2,
#   'rating': 4.3,
#   'reference': 'ChIJkXGesUSaRIYRYuTWrq7szQ0',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 287},
#  '608 Brewing Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '83 Copeland Ave, La Crosse, WI 54603, United States',
#   'geometry': {'location': {'lat': 43.8258353, 'lng': -91.24988979999999},
#    'viewport': {'northeast': {'lat': 43.82717557989272,
#      'lng': -91.24826077010728},
#     'southwest': {'lat': 43.82447592010728, 'lng': -91.25096042989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': '608 Brewing Company',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3036,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103518138679806821841">Ben Fyvie</a>'],
#     'photo_reference': 'ATtYBwIZw0kBodb7lBIBQ-gfNgTL3cV6Z_BKkaDe4JRO7J3avapSHWyZ9SI4vql_CtODa67I_TicsnkJoNkhRsEQVYbjSPTOixzVsRDfU7wQfJVSsvq79eyhAN7fyk1D4oC_rVnswyPwFyMZYnlspBoV6ZOJH_YHVZU9rdear8Zm2N1lLWPR',
#     'width': 4048}],
#   'place_id': 'ChIJe0slaP9U-YcRv96Sx7C4KTw',
#   'plus_code': {'compound_code': 'RQG2+82 La Crosse, Wisconsin',
#    'global_code': '86MCRQG2+82'},
#   'rating': 4.7,
#   'reference': 'ChIJe0slaP9U-YcRv96Sx7C4KTw',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 157},
#  '7 Hermits Brewing Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '278 Hanson Ranch Rd, Vail, CO 81657, United States',
#   'geometry': {'location': {'lat': 39.6398077, 'lng': -106.3731513},
#    'viewport': {'northeast': {'lat': 39.64134037989272,
#      'lng': -106.3717006201073},
#     'southwest': {'lat': 39.63864072010728, 'lng': -106.3744002798927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': '7 Hermits Brewing Company',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105124649681956853435">A M</a>'],
#     'photo_reference': 'ATtYBwLzttwOlPddr7TEhAw3sP9ndlszCHpDW0n9ghrBUVRVwIGv5q4boWn_n4urv01O4gdQVzFCbegmUjL9g4-FQ6xOFWykkoobnJVc6lMMi7hA8dX6JKU5xd_o6rhWS7c8q-ERf7jeLR1vvUk2psUn6PeGaCqfn3PNffowyISxwEb18JL7',
#     'width': 4032}],
#   'place_id': 'ChIJ1aTktohxaocRSksTt_L1Q4c',
#   'plus_code': {'compound_code': 'JJQG+WP Vail, Colorado',
#    'global_code': '85FMJJQG+WP'},
#   'rating': 4.4,
#   'reference': 'ChIJ1aTktohxaocRSksTt_L1Q4c',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 38},
#  '7 Hills Brewing Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '1085 Washington St, Dubuque, IA 52001, United States',
#   'geometry': {'location': {'lat': 42.504616, 'lng': -90.663603},
#    'viewport': {'northeast': {'lat': 42.50599237989272,
#      'lng': -90.66216077010728},
#     'southwest': {'lat': 42.50329272010728, 'lng': -90.66486042989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': '7 Hills Brewing Company',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 932,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101868311229982357417">A Google User</a>'],
#     'photo_reference': 'ATtYBwI7YcPbPbCjVljYkxTJ2qA8iM1NTNdHw0uY0RLzkY_53KCVuenLZ2veFMk5VmCMXboGBxeHUnVFfk49GstavGsSUyod6O7ZZlSMfYHQl_E6n68FpXi7PczX7eqQTphmp6vVdli0DyoDsM3p3x3_6zPWflJtk_B8_YZU5IfPpm6LEilY',
#     'width': 1656}],
#   'place_id': 'ChIJix9b-Zsr44cRhZgPsJOQ4ys',
#   'plus_code': {'compound_code': 'G83P+RH Dubuque, Iowa',
#    'global_code': '86JFG83P+RH'},
#   'price_level': 2,
#   'rating': 4.5,
#   'reference': 'ChIJix9b-Zsr44cRhZgPsJOQ4ys',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 884},
#  '841 Brewhouse': {'business_status': 'OPERATIONAL',
#   'formatted_address': '841 E Milwaukee St, Whitewater, WI 53190, United States',
#   'geometry': {'location': {'lat': 42.8320611, 'lng': -88.7138878},
#    'viewport': {'northeast': {'lat': 42.83353892989272,
#      'lng': -88.71249117010728},
#     'southwest': {'lat': 42.83083927010728, 'lng': -88.71519082989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': '841 Brewhouse',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 518,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107582602694508363398">A Google User</a>'],
#     'photo_reference': 'ATtYBwL-RiWphVaKOAYdxLJo_bTw1iJOd26UnnwGGuEzZQjeMdTCDTPOHrpT7kkAzgwJawD6vhfUf7n0WyiFf7BbVaAugJ7gfWIWWPBrt0bMHs7Vgs9DVQy47t-DQUibQ5HM_YlZCmFZV-dsMODRMSxf4kygOGekMij_dafPRm2itiRKhOrq',
#     'width': 339}],
#   'place_id': 'ChIJ38Yid8zgBYgRsebbxCWzvuI',
#   'plus_code': {'compound_code': 'R7JP+RC Whitewater, Wisconsin',
#    'global_code': '86JHR7JP+RC'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJ38Yid8zgBYgRsebbxCWzvuI',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 620},
#  '903 Brewers': {'business_status': 'OPERATIONAL',
#   'formatted_address': '1718 S Elm St, Sherman, TX 75090, United States',
#   'geometry': {'location': {'lat': 33.6172681, 'lng': -96.60702979999999},
#    'viewport': {'northeast': {'lat': 33.61864242989273,
#      'lng': -96.60554692010729},
#     'southwest': {'lat': 33.61594277010728, 'lng': -96.60824657989274}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': '903 Brewers',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 457,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111802576425019717452">A Google User</a>'],
#     'photo_reference': 'ATtYBwINs2FOGi9SbUo65ta-xEE-8U65LdCigt51W5-VxbXJQ6EcYX5DlJnku4cEo8jZSX5sUMBGNsUx9PIPpgAjz0jIDErNvc87pdD0O1FieIQ4FG40rB_hhk_IXUmbylPthJiCru_I1rbqe7K6zXxRoi7mgzI_Ccgo55Rtuaowh8LbgZwv',
#     'width': 1024}],
#   'place_id': 'ChIJAcxKsJ1iTIYRojBEa1GyFZI',
#   'plus_code': {'compound_code': 'J98V+W5 Sherman, Texas',
#    'global_code': '8655J98V+W5'},
#   'rating': 4.6,
#   'reference': 'ChIJAcxKsJ1iTIYRojBEa1GyFZI',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 155},
#  'Aberrant Ales': {'business_status': 'OPERATIONAL',
#   'formatted_address': '219 W Grand River Ave, Howell, MI 48843, United States',
#   'geometry': {'location': {'lat': 42.6076332, 'lng': -83.9314247},
#    'viewport': {'northeast': {'lat': 42.60905407989272,
#      'lng': -83.93002637010727},
#     'southwest': {'lat': 42.60635442010727, 'lng': -83.93272602989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Aberrant Ales',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1536,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108333463592138112321">A Google User</a>'],
#     'photo_reference': 'ATtYBwKADuUBMQV5REh0aPUup1uHFCvAzln_NzqPULJRAG_uK5b8z2gfWlKpVMHgrfkm-JQIj1J1OtbuOTVC9CsKf-2QldhWA1eFyYzu5WMXZvydCgR9FGjsq3n_qrd9LJm7n2jvR61m-vlg49PF8n5bJrCJeGN2w58aQPbimyMwBylGUW7O',
#     'width': 2048}],
#   'place_id': 'ChIJ_U98j19HI4gRkfoTPCXc6KI',
#   'plus_code': {'compound_code': 'J359+3C Howell, Michigan',
#    'global_code': '86JRJ359+3C'},
#   'rating': 4.3,
#   'reference': 'ChIJ_U98j19HI4gRkfoTPCXc6KI',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 191},
#  'Abolitionist Ale Works': {'business_status': 'OPERATIONAL',
#   'formatted_address': '129 W Washington St #1529, Charles Town, WV 25414, United States',
#   'geometry': {'location': {'lat': 39.2886375, 'lng': -77.8608581},
#    'viewport': {'northeast': {'lat': 39.29003477989272,
#      'lng': -77.85954292010729},
#     'southwest': {'lat': 39.28733512010727, 'lng': -77.86224257989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Abolitionist Ale Works',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2048,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118182198391131593087">A Google User</a>'],
#     'photo_reference': 'ATtYBwIFD7RAl-FVqGDAIDpPoEBfnskm_j_oOHw3bDF3hcCr_q3k1XUJ2b0ygUTU9MSxT4ff_GbWjzJ_vUEPaDQ4C7b44rgDlQ2srUl2nOzSeEDno88urYISqhbknEFMI2lDMLrBvqtmli6xXSodzsNnHjbxYZb2F_RR5y8Lo31t9FzUQUtn',
#     'width': 2048}],
#   'place_id': 'ChIJ_bK8XhMBtokRKa6qMs20_lE',
#   'plus_code': {'compound_code': '74QQ+FM Charles Town, West Virginia',
#    'global_code': '87F474QQ+FM'},
#   'rating': 4.6,
#   'reference': 'ChIJ_bK8XhMBtokRKa6qMs20_lE',
#   'types': ['bar',
#    'liquor_store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 165},
#  'Abridged Beer Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '100 Lockett Rd, Knoxville, TN 37919, United States',
#   'geometry': {'location': {'lat': 35.931667, 'lng': -84.015609},
#    'viewport': {'northeast': {'lat': 35.93292542989273,
#      'lng': -84.01436337010728},
#     'southwest': {'lat': 35.93022577010728, 'lng': -84.01706302989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Abridged Beer Company',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115160633094032050956">Sacheta Singh</a>'],
#     'photo_reference': 'ATtYBwKZhI0TRQC579y2QJFXE_6NeOxRJyxx9aVuXuw53qt5J5ILatPjs7NnKNh4XAKZaYzVV9_XKmMU93NcFNTnNME4VcGLRQCApxTGOLFARsbI4ISxR3Ibqjrb78wIdjvYP_BOK5MGHAsDzKBnHvkYNkMiXPQIqa6vpg5CVCUM2fOBNz1f',
#     'width': 4032}],
#   'place_id': 'ChIJZcWOyFcjXIgR1CVIcBPDe5g',
#   'plus_code': {'compound_code': 'WXJM+MQ Knoxville, Tennessee',
#    'global_code': '867QWXJM+MQ'},
#   'price_level': 2,
#   'rating': 4.7,
#   'reference': 'ChIJZcWOyFcjXIgR1CVIcBPDe5g',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 825},
#  'Accomplice Beer Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '115 W 15th St, Cheyenne, WY 82001, United States',
#   'geometry': {'location': {'lat': 41.131904, 'lng': -104.814096},
#    'viewport': {'northeast': {'lat': 41.13333667989272,
#      'lng': -104.8128008201073},
#     'southwest': {'lat': 41.13063702010728, 'lng': -104.8155004798927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Accomplice Beer Company',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101231005243700698590">Accomplice Beer Company</a>'],
#     'photo_reference': 'ATtYBwIMqQ_pwvadkuOqCtC4uMeHrKIk98T0AKFl5qp_EsEk5JTTJYc-uIyn0IuImF2uRbPv8quoHGKIERvR1hheAnDaiHQYduQn2DIapR5DGxg0M-ij8uRF_TSW1frVATvbjAtReVR07Up5fq7CM3ArVGOPsUg7voM3dhqpWNCapOXYZqWM',
#     'width': 3000}],
#   'place_id': 'ChIJm8zPhMM6b4cRr3nTiWG6O_s',
#   'plus_code': {'compound_code': '45JP+Q9 Cheyenne, Wyoming',
#    'global_code': '85HQ45JP+Q9'},
#   'rating': 4.1,
#   'reference': 'ChIJm8zPhMM6b4cRr3nTiWG6O_s',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 404},
#  'Acorn Brewing': {'business_status': 'OPERATIONAL',
#   'formatted_address': '2105 Meridian Ave E, Edgewood, WA 98371, United States',
#   'geometry': {'location': {'lat': 47.2379565, 'lng': -122.2934912},
#    'viewport': {'northeast': {'lat': 47.23930712989272,
#      'lng': -122.2923800701073},
#     'southwest': {'lat': 47.23660747010728, 'lng': -122.2950797298927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Acorn Brewing',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109407548451459570567">Harris Hamburg</a>'],
#     'photo_reference': 'ATtYBwJx_0bMnuWYtHk0l94xGHIVjL8jMpI4IMPO0GIpklMUV5SHb1l7mwT93HxurgkOojVLUAKYMbKRtegy5DtBICHoLNy10YSYomHnNeIy5VAkmUew0asO1pmXk7mMNUcFPCZ5vQitHHL2AXZ-3ZBvqWsPgJ1V4GAQtc7T2-EVqLYibDqu',
#     'width': 4032}],
#   'place_id': 'ChIJa8jPlJX5kFQRzE8LRbk-DRs',
#   'plus_code': {'compound_code': '6PQ4+5J Edgewood, Washington',
#    'global_code': '84VV6PQ4+5J'},
#   'rating': 4.8,
#   'reference': 'ChIJa8jPlJX5kFQRzE8LRbk-DRs',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 89},
#  'Adams Street Brewery': {'business_status': 'CLOSED_TEMPORARILY',
#   'formatted_address': '17 W Adams St, Chicago, IL 60603, United States',
#   'geometry': {'location': {'lat': 41.87923199999999, 'lng': -87.6283942},
#    'viewport': {'northeast': {'lat': 41.88069092989272,
#      'lng': -87.62704892010728},
#     'southwest': {'lat': 41.87799127010727, 'lng': -87.62974857989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Adams Street Brewery',
#   'permanently_closed': True,
#   'photos': [{'height': 900,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100842203663546458406">A Google User</a>'],
#     'photo_reference': 'ATtYBwL6LZ_Ju4AfGOP0dKWj0Qd0-O53y8dNt-he6S_JrlnRIBUu13LR9Sq38ZHJkseL6eOMkMAvVYE5N_nC-xypY0ZFMR0ci6LlkE3mCPO1-vyt7VDSKU4c4njPQ94ScfcCQ2o7LoneezoR2srAxdj63v9i78XH7ZR1Hk5rQsbGSjPwJEc_',
#     'width': 1440}],
#   'place_id': 'ChIJD2qt8UotDogRGD52rCgUD7o',
#   'plus_code': {'compound_code': 'V9HC+MJ Chicago, Illinois',
#    'global_code': '86HJV9HC+MJ'},
#   'rating': 4.6,
#   'reference': 'ChIJD2qt8UotDogRGD52rCgUD7o',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 46},
#  'Aisle 5': {'business_status': 'OPERATIONAL',
#   'formatted_address': '1123 Euclid Ave NE, Atlanta, GA 30307, United States',
#   'geometry': {'location': {'lat': 33.7643442, 'lng': -84.3504133},
#    'viewport': {'northeast': {'lat': 33.76572772989271,
#      'lng': -84.34910087010726},
#     'southwest': {'lat': 33.76302807010727, 'lng': -84.35180052989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Aisle 5',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3265,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116237027913673287579">Bradley Huchteman</a>'],
#     'photo_reference': 'ATtYBwI7vZlcDUV37rqaiaAIzeJiR5VADFifXOxooZmyPfZRvBVen0ym6pBfytSuBnzqM6HmJi55dqEF9gm_GBkL3QtzikuRhipWcj97ztf_QDIaPLEzw8OBlxbo3_U8-Noau4BZtICIOtxFbXhUNWMHOprLs5fRmEkwJTmMYyMu5RD1u9-P',
#     'width': 4898}],
#   'place_id': 'ChIJ05YhFqkG9YgRVCIPgWRCFi8',
#   'plus_code': {'compound_code': 'QJ7X+PR Atlanta, Georgia',
#    'global_code': '865QQJ7X+PR'},
#   'price_level': 2,
#   'rating': 4.6,
#   'reference': 'ChIJ05YhFqkG9YgRVCIPgWRCFi8',
#   'types': ['point_of_interest', 'establishment'],
#   'user_ratings_total': 438},
#  'Akademia Brewing Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '150 Crane Dr, Athens, GA 30606, United States',
#   'geometry': {'location': {'lat': 33.9420243, 'lng': -83.470473},
#    'viewport': {'northeast': {'lat': 33.94345672989272,
#      'lng': -83.46936557010729},
#     'southwest': {'lat': 33.94075707010728, 'lng': -83.47206522989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Akademia Brewing Company',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2160,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112026350287161070354">Akademia Brewing Company</a>'],
#     'photo_reference': 'ATtYBwJ_6kbJsoKnYYX0AegVlJNCvqOehJR1i6kkxsXB_8MhwAoHSk52EuOItTZMm2fqOupfSZBKq2-UUDga5ZwMUb9MMWT_qF7VWchBHLT7z_Zcpy4K3Xlk8MEbrv0y9qEfZYwNjgBh6ciChe7PDtNvuppJmmMuwvES7iaKY6uro3N5jKvg',
#     'width': 2160}],
#   'place_id': 'ChIJN1DEEQRz9ogRkYeni_kx7sk',
#   'plus_code': {'compound_code': 'WGRH+RR Athens, Georgia',
#    'global_code': '865RWGRH+RR'},
#   'price_level': 2,
#   'rating': 4.6,
#   'reference': 'ChIJN1DEEQRz9ogRkYeni_kx7sk',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 806},
#  'Alaro Craft Brewery': {'business_status': 'OPERATIONAL',
#   'formatted_address': '2004 Capitol Ave, Sacramento, CA 95811, United States',
#   'geometry': {'location': {'lat': 38.5731152, 'lng': -121.4810826},
#    'viewport': {'northeast': {'lat': 38.57454262989272,
#      'lng': -121.4797001201072},
#     'southwest': {'lat': 38.57184297010728, 'lng': -121.4823997798927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Alaro Craft Brewery',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2832,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105747737638959474330">A Google User</a>'],
#     'photo_reference': 'ATtYBwJUw2QhE488tZIFlaCSLStNUuaB9JPsA00MrkQVSJIug2HRRHqi8p_l3QbT0kumeLKeXYo-hmSTMQlFGR3hPl_D94mRXeXTZn_XVHQ_oAFxnyy4gX6lsItR1PKu1wjf-pTM28RFXjl5owu-KscSP8iUx19pfIKESthpYce4D8bf4xJp',
#     'width': 4256}],
#   'place_id': 'ChIJQ39oHI3RmoARLa8laA8OeQ4',
#   'plus_code': {'compound_code': 'HGF9+6H Sacramento, California',
#    'global_code': '84CWHGF9+6H'},
#   'price_level': 2,
#   'rating': 4.5,
#   'reference': 'ChIJQ39oHI3RmoARLa8laA8OeQ4',
#   'types': ['restaurant',
#    'meal_takeaway',
#    'bar',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 230},
#  'Alcona Brew Haus': {'business_status': 'OPERATIONAL',
#   'formatted_address': '676 N U.S. 23, Harrisville, MI 48740, United States',
#   'geometry': {'location': {'lat': 44.67568, 'lng': -83.2903912},
#    'viewport': {'northeast': {'lat': 44.67704367989272,
#      'lng': -83.28935372010727},
#     'southwest': {'lat': 44.67434402010728, 'lng': -83.2920533798927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Alcona Brew Haus',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103400263469331867895">Rockstroh Friz</a>'],
#     'photo_reference': 'ATtYBwJ0coiwR_5o8hC8MCvRFhjoLUuyAAorAOeEYU7MsRcjP8enoRd_xmTrVNyQmGArTWzbXUXhuqjqUPmUY8LRAhRUic5HlsKadd7jqPqNaS_vTU5HgidRj3adFCg8GEBx0oLKjuw9Yu7hXaSmiW6cw5PKEY9iEqVsYp7rwlGwe7C-w_1O',
#     'width': 4032}],
#   'place_id': 'ChIJnxZwRFJdJ4gR_iYIIApF2Ro',
#   'plus_code': {'compound_code': 'MPG5+7R Harrisville, Michigan',
#    'global_code': '86PRMPG5+7R'},
#   'price_level': 2,
#   'rating': 4.6,
#   'reference': 'ChIJnxZwRFJdJ4gR_iYIIApF2Ro',
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 333},
#  'Ale Republic': {'business_status': 'OPERATIONAL',
#   'formatted_address': '28 Arroyo Seco Rd, Cedar Crest, NM 87008, United States',
#   'geometry': {'location': {'lat': 35.1285937, 'lng': -106.3651288},
#    'viewport': {'northeast': {'lat': 35.13012222989271,
#      'lng': -106.3637026701073},
#     'southwest': {'lat': 35.12742257010727, 'lng': -106.3664023298927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Ale Republic',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103836814659518854685">Michael Bzdell</a>'],
#     'photo_reference': 'ATtYBwJLoJhU_ZHKvkAYBXCUXegQSm6ABJL5kMFcT4ZPhFZF4hh-d4YGZq2NGLh29x9Mp_1gjCiL5H_6ja8wyqfaafg5RtNwXuHTLWv8he5dtHsq3JFe09-rCn34ytO-s7Ku6pAhcs-yUPqr-AA_6rOVPkV-Jdnh4xEGZMJEO7r2J_O7gSg',
#     'width': 4032}],
#   'place_id': 'ChIJTSbeu7yiGIcRBstHhRVAeQA',
#   'plus_code': {'compound_code': '4JHM+CW Cedar Crest, New Mexico',
#    'global_code': '857M4JHM+CW'},
#   'rating': 4.8,
#   'reference': 'ChIJTSbeu7yiGIcRBstHhRVAeQA',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 191},
#  'Alebird Taphouse and Brewery': {'business_status': 'OPERATIONAL',
#   'formatted_address': '2619 84th St SW, Byron Center, MI 49315, United States',
#   'geometry': {'location': {'lat': 42.8123817, 'lng': -85.7286432},
#    'viewport': {'northeast': {'lat': 42.81365222989272,
#      'lng': -85.72729442010728},
#     'southwest': {'lat': 42.81095257010728, 'lng': -85.72999407989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Alebird Taphouse and Brewery',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3036,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112871883130577089571">Robin Barker</a>'],
#     'photo_reference': 'ATtYBwIH1_wgKNmLyf95ozf77mx_E3YMCKPoiY1A-aCJpCQj7EB69V4F_LC9qdloinZV7uW3l0HAsHdzKixjiAt22Yf-0uSJwAtKEQHou7dAr4kgVbTvXL1ikJYASF2MZIXCJsUpIgG2C8dCE80bAjbZKvgGnau1EyuymCiJ4XEiOZW73nLv',
#     'width': 3684}],
#   'place_id': 'ChIJB2Mctqi3GYgRwg2zZp_xiTI',
#   'plus_code': {'compound_code': 'R76C+XG Byron Center, Michigan',
#    'global_code': '86JPR76C+XG'},
#   'rating': 4,
#   'reference': 'ChIJB2Mctqi3GYgRwg2zZp_xiTI',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 178},
#  'StormBreaker Brewing': {'business_status': 'OPERATIONAL',
#   'formatted_address': '832 N Beech St, Portland, OR 97227, United States',
#   'geometry': {'location': {'lat': 45.549428, 'lng': -122.675145},
#    'viewport': {'northeast': {'lat': 45.55085467989272,
#      'lng': -122.6738448201073},
#     'southwest': {'lat': 45.54815502010728, 'lng': -122.6765444798927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'StormBreaker Brewing',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 481,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104854865844890142837">StormBreaker Brewing</a>'],
#     'photo_reference': 'ATtYBwIOSyGwlokBbdbmwOsNcZm-o0YAR8Sa0MidZbwxTK4W8XW-cvwRjpky9QyKZML0SInvqW1fNyICtk3oVtgmxIdA_2oJl24B8fKmh27OOmjSPf-bm928PMbn_USd66gaDNcUEmDWhIBneLaEQLfFecC9glhNmpGKpu3LosqRUP4h1KxL',
#     'width': 720}],
#   'place_id': 'ChIJ5feGCGqnlVQRV2Lc8MyL8e0',
#   'plus_code': {'compound_code': 'G8XF+QW Portland, Oregon',
#    'global_code': '84QVG8XF+QW'},
#   'rating': 4.5,
#   'reference': 'ChIJ5feGCGqnlVQRV2Lc8MyL8e0',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 407},
#  'Alewife Brewing Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '41-11 39th St, Sunnyside, NY 11104, United States',
#   'geometry': {'location': {'lat': 40.746935, 'lng': -73.925239},
#    'viewport': {'northeast': {'lat': 40.74830297989272,
#      'lng': -73.92405162010728},
#     'southwest': {'lat': 40.74560332010728, 'lng': -73.92675127989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Alewife Brewing Company',
#   'photos': [{'height': 1182,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105399176927152715005">A Google User</a>'],
#     'photo_reference': 'ATtYBwJO8qYFEf5zJ-_dhNpXpHjR6fFBFCobncA1m87NQY7GJWB-gKGqbpKxqr8gF8KibLjAkGaAqSHtHL53GhQZdoidAIA_55-2IvxaHmZef4jTdFkZ_M8spiyITlcfZEYlvUCSb233U-xLo6HBY9nMHEWX0Qf2OzE_VxIfeoFDSJ1kbCTV',
#     'width': 1080}],
#   'place_id': 'ChIJ3Rw-m_pfwokRw75q9LFrztk',
#   'plus_code': {'compound_code': 'P3WF+QW New York',
#    'global_code': '87G8P3WF+QW'},
#   'rating': 5,
#   'reference': 'ChIJ3Rw-m_pfwokRw75q9LFrztk',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 2},
#  'Alien Brewpub': {'business_status': 'OPERATIONAL',
#   'formatted_address': '6601 Uptown Blvd NE, Albuquerque, NM 87110, United States',
#   'geometry': {'location': {'lat': 35.1041497, 'lng': -106.571126},
#    'viewport': {'northeast': {'lat': 35.10550007989272,
#      'lng': -106.5697159201073},
#     'southwest': {'lat': 35.10280042010727, 'lng': -106.5724155798927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#   'name': 'Alien Brewpub',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103458058598329835059">carl tabor</a>'],
#     'photo_reference': 'ATtYBwIBp_1LAqobH0fsr6_EqaIuddEN4P8XWwgl3d8CXUtwCyqVYq96ngv7TYTQQZPDzZuuQaVDna6d_PX358an8hHFS1vgGgmUff74RBdSJV3U9_yevkAdQjbS_8aC7NJNMiki9mNbA7X_sO_6Jew34d5zQy1xO7_pPpbBw-UFcoYIV2fM',
#     'width': 4032}],
#   'place_id': 'ChIJ9aev09EKIocRDlkA6diwJ_0',
#   'plus_code': {'compound_code': '4C3H+MG Albuquerque, New Mexico',
#    'global_code': '857M4C3H+MG'},
#   'price_level': 2,
#   'rating': 4.1,
#   'reference': 'ChIJ9aev09EKIocRDlkA6diwJ_0',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 271},
#  'All Sevens Brewing': {'business_status': 'OPERATIONAL',
#   'formatted_address': '777 Haywood Rd, Asheville, NC 28806, United States',
#   'geometry': {'location': {'lat': 35.5786716, 'lng': -82.59443069999999},
#    'viewport': {'northeast': {'lat': 35.57996897989273,
#      'lng': -82.59311662010727},
#     'southwest': {'lat': 35.57726932010728, 'lng': -82.59581627989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'All Sevens Brewing',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105046328635157237905">Dori Roberts</a>'],
#     'photo_reference': 'ATtYBwIPBLE0hfn0E6UiJZmXeGNJTtBEhn0JwRZ3blAv6rkTSztWS0VckRmuBJzC3XOdI4T-AbGVALX1pBGEWb26OsGmOmlzOZHDw3FQqNfaRxW93eM4oDRHqnbsVDpj2EQIWjki8xDgjUPtmhUnsCM7JRZTDc2xaF5KTfoBemposSHltQoG',
#     'width': 3024}],
#   'place_id': 'ChIJa762ERGNWYgRPeTnpBZQSiU',
#   'plus_code': {'compound_code': 'HCH4+F6 Asheville, North Carolina',
#    'global_code': '867VHCH4+F6'},
#   'rating': 4.7,
#   'reference': 'ChIJa762ERGNWYgRPeTnpBZQSiU',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 7},
#  'Alvarado Street Brewery': {'business_status': 'OPERATIONAL',
#   'formatted_address': '426 Alvarado St, Monterey, CA 93940, United States',
#   'geometry': {'location': {'lat': 36.5993111, 'lng': -121.8948056},
#    'viewport': {'northeast': {'lat': 36.60065522989272,
#      'lng': -121.8933181701073},
#     'southwest': {'lat': 36.59795557010727, 'lng': -121.8960178298927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Alvarado Street Brewery',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100890989013973478703">Jerry Ham</a>'],
#     'photo_reference': 'ATtYBwKWaYJ_8b_xFB0deLrCTf75SAIdSwIF9N0y1_CxrNyGkT_gCy1JDmllWdMFzGIMItFlVOdlLCLWM8H2bFlyfr0xyifgvReN32EjeZvZsIei23b1YD7uft3tMFD7cap-e0HNw5nIpz-VdoFsD_UXr_qoVMrpZsFLRJAf8peSHQ0sloOj',
#     'width': 4032}],
#   'place_id': 'ChIJ0SbE6iPkjYARnHafeDarrWg',
#   'plus_code': {'compound_code': 'H4X4+P3 Monterey, California',
#    'global_code': '848WH4X4+P3'},
#   'price_level': 1,
#   'rating': 4.5,
#   'reference': 'ChIJ0SbE6iPkjYARnHafeDarrWg',
#   'types': ['meal_takeaway',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 952},
#  'Amber Lantern Brewing Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '44 N Main St, Warsaw, NY 14569, United States',
#   'geometry': {'location': {'lat': 42.7408333, 'lng': -78.1322222},
#    'viewport': {'northeast': {'lat': 42.74218237989271,
#      'lng': -78.13105687010727},
#     'southwest': {'lat': 42.73948272010727, 'lng': -78.13375652989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Amber Lantern Brewing Company',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2448,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105901757574077534071">Tommy Streamer</a>'],
#     'photo_reference': 'ATtYBwJmmz2v-4pRW39qSgPGpcslZFyNhpuchjbGW-ebJ8OEgOc3ZHQPnyXEq80Ui0hWig_ZiXsXT-yvuGU5u-dD3e6g4gMMYf8lJ5NGOkebNVCfwQAbJXjXhp3dyMa0ldS9KYiHbkFI4w-HjPt0X9M-VLMlUceWMstyWBwqht4JwFX-iLZl',
#     'width': 3264}],
#   'place_id': 'ChIJKf6eSz3F04kRxgXE-gu7DWc',
#   'plus_code': {'compound_code': 'PVR9+84 Warsaw, New York',
#    'global_code': '87J3PVR9+84'},
#   'rating': 4.3,
#   'reference': 'ChIJKf6eSz3F04kRxgXE-gu7DWc',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 75},
#  'American Craft Aleworks': {'business_status': 'OPERATIONAL',
#   'formatted_address': '200 Clematis St, West Palm Beach, FL 33401, United States',
#   'geometry': {'location': {'lat': 26.7131429, 'lng': -80.0508325},
#    'viewport': {'northeast': {'lat': 26.71457252989272,
#      'lng': -80.04948157010728},
#     'southwest': {'lat': 26.71187287010728, 'lng': -80.05218122989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'American Craft Aleworks',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117634755381339559986">A Google User</a>'],
#     'photo_reference': 'ATtYBwK7tAHyFgc5E2qJAl58IHR7b3vi3ot1Nz8lUDfdNo60oTbxG0ozCz_uz_dv53PkfZEIJ0mIbK1fbggp8AwERg-QiHI_9oWWGjFWmKCHFKNsgA1fJ7pwPDjfEKHylycAIc2tgMz7KpqtfSywxvfdDuAO0Ge3_QuxvRnYGEHAmTm30yRd',
#     'width': 4032}],
#   'place_id': 'ChIJk_4XStbX2IgR11fpYbukghk',
#   'plus_code': {'compound_code': 'PW7X+7M West Palm Beach, Florida',
#    'global_code': '76RXPW7X+7M'},
#   'rating': 4.6,
#   'reference': 'ChIJk_4XStbX2IgR11fpYbukghk',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 179},
#  'American Icon Brewery': {'business_status': 'OPERATIONAL',
#   'formatted_address': '1133 19th Pl, Vero Beach, FL 32960, United States',
#   'geometry': {'location': {'lat': 27.6373994, 'lng': -80.39711510000001},
#    'viewport': {'northeast': {'lat': 27.63889527989272,
#      'lng': -80.39580917010727},
#     'southwest': {'lat': 27.63619562010728, 'lng': -80.39850882989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'American Icon Brewery',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3036,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101753274292371825837">CMB Caspanello</a>'],
#     'photo_reference': 'ATtYBwIdEK5mWapLClAeu4w6ksUxoZQP4gRNjPH-BkYF7TiTxWqD8gA860nAQL8XmVe8GV8Ru5uV7wvLcEwLPekfYmf0qSnXP1NkbDTk_m-XL6ZK7E9xXgFTg_XglUVHlLgVKBeXVHKQpCJWM_UnfLsORdGFkyw0Luyw4E1QC7DiX9HmhfWY',
#     'width': 4048}],
#   'place_id': 'ChIJP8XNZB1f3ogRttJ3N-GvECk',
#   'plus_code': {'compound_code': 'JJP3+X5 Vero Beach, Florida',
#    'global_code': '76VXJJP3+X5'},
#   'price_level': 2,
#   'rating': 4.2,
#   'reference': 'ChIJP8XNZB1f3ogRttJ3N-GvECk',
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 743},
#  'American Icon Brewery Kitchen & Taproom': {'business_status': 'OPERATIONAL',
#   'formatted_address': '911 NE 4th Ave, Fort Lauderdale, FL 33304, United States',
#   'geometry': {'location': {'lat': 26.1356175, 'lng': -80.1407187},
#    'viewport': {'northeast': {'lat': 26.13697117989273,
#      'lng': -80.13921437010727},
#     'southwest': {'lat': 26.13427152010728, 'lng': -80.14191402989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'American Icon Brewery Kitchen & Taproom',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103149477712677711126">Sherry</a>'],
#     'photo_reference': 'ATtYBwI8F_eR7WyWQ9O0r4n48DK7E9cHxA3i5OI5quu7nAy150fDIuAUJ14emKZ4EGMQv3U3rj_hPuxckT2cVGLIV_9CXWuX74ryb7Wo14Wn4WwwZq4YGVoUPW0XpH34MJanrKUc_bwNXeAXXO_lLeTwq53wVaXlPMfv8Rt76rua5mWoLsTK',
#     'width': 4032}],
#   'place_id': 'ChIJyXlURo4B2YgRMCyYB8IivCY',
#   'plus_code': {'compound_code': '4VP5+6P Fort Lauderdale, Florida',
#    'global_code': '76RX4VP5+6P'},
#   'rating': 4.3,
#   'reference': 'ChIJyXlURo4B2YgRMCyYB8IivCY',
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 114},
#  'Amery Ale Works': {'business_status': 'OPERATIONAL',
#   'formatted_address': '588 115th St, Amery, WI 54001, United States',
#   'geometry': {'location': {'lat': 45.2937441, 'lng': -92.396994},
#    'viewport': {'northeast': {'lat': 45.29510487989272,
#      'lng': -92.39610582010727},
#     'southwest': {'lat': 45.29240522010728, 'lng': -92.39880547989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#   'name': 'Amery Ale Works',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3056,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103454418118468642962">Amery Ale Works</a>'],
#     'photo_reference': 'ATtYBwLYJ9JU2gZKacpwjYia3f4fsT6ZW6-hZYUwE4xxlBLA_q91uIIfuTfklEU1mW7ZeKj7hD4ijh93FNSD6PCAROvhnTvS84HoN3Q9lpxG6-MlEhiTBLdBKm6xnZbOylchF6_VDxuVtppIXdvplzD6unoZZ_zC9V4Qiyd2JHxBoA-tOarm',
#     'width': 4592}],
#   'place_id': 'ChIJk3OMIThnrVIRScVZL4oO0Xg',
#   'plus_code': {'compound_code': '7JV3+F6 Amery, Wisconsin',
#    'global_code': '86Q97JV3+F6'},
#   'price_level': 2,
#   'rating': 4.7,
#   'reference': 'ChIJk3OMIThnrVIRScVZL4oO0Xg',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 203},
#  'Amici Madison': {'business_status': 'OPERATIONAL',
#   'formatted_address': '174 W Washington St, Madison, GA 30650, United States',
#   'geometry': {'location': {'lat': 33.5961543, 'lng': -83.4693612},
#    'viewport': {'northeast': {'lat': 33.59753812989272,
#      'lng': -83.46799367010728},
#     'southwest': {'lat': 33.59483847010728, 'lng': -83.47069332989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Amici Madison',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108028977527067550642">A Google User</a>'],
#     'photo_reference': 'ATtYBwI1ZNIOb5A6gVufA_Py4zrodE9cT-z_I1a9TkHDHOX7Px1kKW2m-vkSNVO-kWU_whuHKfLnvpFE17yFU6aLSxet4Y4UmyBRcWPDf9TT3KKT9VP38ODRBZ9DwjlTkF6CcpNSOmwtu23rCPeHnXL69GceM1GxpgEnN34IiLX51YWwsd29',
#     'width': 1500}],
#   'place_id': 'ChIJj6MDQQmH9ogRqrC9zKtng00',
#   'plus_code': {'compound_code': 'HGWJ+F7 Madison, Georgia',
#    'global_code': '865RHGWJ+F7'},
#   'price_level': 2,
#   'rating': 4.3,
#   'reference': 'ChIJj6MDQQmH9ogRqrC9zKtng00',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 483},
#  'Amplified Ale Works': {'business_status': 'OPERATIONAL',
#   'formatted_address': '9030 Kenamar Dr #309, San Diego, CA 92121, United States',
#   'geometry': {'location': {'lat': 32.8866868, 'lng': -117.1570373},
#    'viewport': {'northeast': {'lat': 32.88803517989273,
#      'lng': -117.1556031701073},
#     'southwest': {'lat': 32.88533552010728, 'lng': -117.1583028298927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Amplified Ale Works',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 639,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100598598363155944891">Amplified Ale Works</a>'],
#     'photo_reference': 'ATtYBwKd_GGNWFPBWdyrQELpswFTIn3jACfK3sX6xzS-Fo98RnG8WJvywqV_IF-fDMHX3lvTHHX2okfWrmLyoChXZW8NgciRHc7G8HYXduj1Xd-l7DNYVLrjLieuMV1EU_OsUKwVJ5y-eFm_emXy8E-5LJUBlH7ikazmlxhxN5zdiqnltqIJ',
#     'width': 1000}],
#   'place_id': 'ChIJlUv4lLP424ART5Q5C9vL62U',
#   'plus_code': {'compound_code': 'VRPV+M5 San Diego, California',
#    'global_code': '8544VRPV+M5'},
#   'rating': 4.7,
#   'reference': 'ChIJlUv4lLP424ART5Q5C9vL62U',
#   'types': ['bar',
#    'liquor_store',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 40},
#  'Angry Troll Brewing': {'business_status': 'OPERATIONAL',
#   'formatted_address': '222 E Main St, Elkin, NC 28621, United States',
#   'geometry': {'location': {'lat': 36.2446326, 'lng': -80.8488066},
#    'viewport': {'northeast': {'lat': 36.24602257989272,
#      'lng': -80.84748022010727},
#     'southwest': {'lat': 36.24332292010727, 'lng': -80.85017987989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Angry Troll Brewing',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1960,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100908810165830962765">Lorne Kerley</a>'],
#     'photo_reference': 'ATtYBwIaA73t19RAXHcfWuV85t7R4PPi5sEY-FrvuOjtyy2Y1nSZyPx9htrMNzNlptQGD64r9mmnVFYgrBmXge7Usg6oUVqXHMeHiuV0oqrrtitxMrOSYDPy9QIAzWdMN1L9d4Re0wvG2acU36-NI6YFqrHpWJkOafRXmF-5HGTHUymU68Cw',
#     'width': 4032}],
#   'place_id': 'ChIJEVTdd5x_UYgR3Xzi7h18n1E',
#   'plus_code': {'compound_code': '65V2+VF Elkin, North Carolina',
#    'global_code': '868X65V2+VF'},
#   'price_level': 2,
#   'rating': 4.3,
#   'reference': 'ChIJEVTdd5x_UYgR3Xzi7h18n1E',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 328},
#  'Anvil Brewing': {'business_status': 'OPERATIONAL',
#   'formatted_address': '115 S Compress St, Pittsburg, TX 75686, United States',
#   'geometry': {'location': {'lat': 32.9964039, 'lng': -94.967303},
#    'viewport': {'northeast': {'lat': 32.99778247989272,
#      'lng': -94.96605872010728},
#     'southwest': {'lat': 32.99508282010728, 'lng': -94.96875837989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Anvil Brewing',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2268,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105424756814192997406">mark yeninas</a>'],
#     'photo_reference': 'ATtYBwIS41XPibQRW7KMZN-yWWWLOwGU2HwB0G5tiNLcUzuv16a_msB_7Cs4BcTn47GIhbt_1OAJgEbp7KXVJSsf1geakxzejfvCOh0_5T9ffXwpQ-o-q_6uv9JbwZUQth4eoV0StAPchsRks9k6VIAFAAYPIUVNsLVrrRFNXy-8OV5dWToq',
#     'width': 4032}],
#   'place_id': 'ChIJWXf54-X9NYYRrzsZMHm-oLM',
#   'plus_code': {'compound_code': 'X2WM+H3 Pittsburg, Texas',
#    'global_code': '8647X2WM+H3'},
#   'price_level': 2,
#   'rating': 4.5,
#   'reference': 'ChIJWXf54-X9NYYRrzsZMHm-oLM',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 238},
#  'Appleton Beer Factory': {'business_status': 'OPERATIONAL',
#   'formatted_address': '603 W College Ave, Appleton, WI 54914, United States',
#   'geometry': {'location': {'lat': 44.2615451, 'lng': -88.4140348},
#    'viewport': {'northeast': {'lat': 44.26303102989272,
#      'lng': -88.41273922010727},
#     'southwest': {'lat': 44.26033137010728, 'lng': -88.41543887989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Appleton Beer Factory',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 683,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115225986671000889434">Appleton Beer Factory</a>'],
#     'photo_reference': 'ATtYBwKi1iEE_F0BUy5KwzCC9n_V9OxOuvPsCDhcXw6ZXe0wBMBchK43gOWcpesOjrkdS8kuyVhb7-n6kWDmisMvFYyjrNxVpiGplDlxkmZKKLL-dU7HqfsNAIfGdEqW64td2sHjSki-EsqIGIjHuCCqxOE7HM-inl489Gz7AaUrHkmIxiEW',
#     'width': 1024}],
#   'place_id': 'ChIJuRiyyTu3A4gRT8_DsvcSMMo',
#   'plus_code': {'compound_code': '7H6P+J9 Appleton, Wisconsin',
#    'global_code': '86PH7H6P+J9'},
#   'rating': 4.1,
#   'reference': 'ChIJuRiyyTu3A4gRT8_DsvcSMMo',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 174},
#  'Arcadia Smokehouse': {'business_status': 'OPERATIONAL',
#   'formatted_address': '2101 E Michigan Ave, Lansing, MI 48912, United States',
#   'geometry': {'location': {'lat': 42.733805, 'lng': -84.52092859999999},
#    'viewport': {'northeast': {'lat': 42.73504422989272,
#      'lng': -84.51957817010727},
#     'southwest': {'lat': 42.73234457010728, 'lng': -84.52227782989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Arcadia Smokehouse',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106912143419990620921">andi nicpon</a>'],
#     'photo_reference': 'ATtYBwLEUGJLEq1BFzAuL-P1hwTM5yro4jdvk_FYD4IPAkWkUc-t5iyrhNYxbvZfZNhYH2497A7Nn-SfZSjhTY0IZcoi-HtKnhiQj3O1mlqi4xvOcOX2lVZFEZDkWgoPc67nZjVsiwS5HKSQDz09R6qMicIcbV8OearD4XbXq71ju2Uz3nf7',
#     'width': 4032}],
#   'place_id': 'ChIJeRrBnLrpIogRulIDA-GEFpU',
#   'plus_code': {'compound_code': 'PFMH+GJ Lansing, Michigan',
#    'global_code': '86JQPFMH+GJ'},
#   'price_level': 2,
#   'rating': 4,
#   'reference': 'ChIJeRrBnLrpIogRulIDA-GEFpU',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 636},
#  'Arcadian Moon': {'business_status': 'OPERATIONAL',
#   'formatted_address': '19203 W E Old Hwy 40, Higginsville, MO 64037, United States',
#   'geometry': {'location': {'lat': 39.0003838, 'lng': -93.75373160000001},
#    'viewport': {'northeast': {'lat': 39.00199497989272,
#      'lng': -93.75236287010729},
#     'southwest': {'lat': 38.99929532010728, 'lng': -93.75506252989274}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'name': 'Arcadian Moon',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117623328429395930322">Sara Evans</a>'],
#     'photo_reference': 'ATtYBwLqgD8OI9feZm-lHe1zg6FoixgikL4X7RvRC5x0tr5SvsClHOZczAwMCczLnfvdWQvebsDRVIUh1T58HSeYqNHg2GiT4QP-qjSKsRLL_mizNyyXO3194Q0E8DK0cwBGg5nDJLvib7lwoDSxXHiIMSfqpWM09xrQKzKRkrbJ8D_5w7ue',
#     'width': 4032}],
#   'place_id': 'ChIJK1UrMe9hwYcRLBwjQokqdTM',
#   'plus_code': {'compound_code': '262W+5G Higginsville, Missouri',
#    'global_code': '86F8262W+5G'},
#   'rating': 4.1,
#   'reference': 'ChIJK1UrMe9hwYcRLBwjQokqdTM',
#   'types': ['liquor_store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 147},
#  'Arrowhead Ales Brewing Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '2101 Calistoga Dr, New Lenox, IL 60451, United States',
#   'geometry': {'location': {'lat': 41.4814956, 'lng': -87.9590444},
#    'viewport': {'northeast': {'lat': 41.48291957989272,
#      'lng': -87.95770007010728},
#     'southwest': {'lat': 41.48021992010727, 'lng': -87.96039972989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Arrowhead Ales Brewing Company',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1152,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110936119170675940680">Arrowhead Ales Brewing Company</a>'],
#     'photo_reference': 'ATtYBwLAy7S5oukCK0TSbVHPdJKuMygE7GT841H79Tch8CqmnZlAkVIawxQM2wJ2qXqluQPZTE9liVqYiOeegM2gDL2Kx-cxNJrvXKLo0-zEQkNnx3XwZ10mcJ65xWbBiYsVX3ibBLfn_Lw5hdJu5xcQO-hTBqFZLj7kPlYw7BpLwifiqw5M',
#     'width': 2048}],
#   'place_id': 'ChIJT_pel-luDogRSOjE3Yhx7Ws',
#   'plus_code': {'compound_code': 'F2JR+H9 New Lenox, Illinois',
#    'global_code': '86HJF2JR+H9'},
#   'price_level': 2,
#   'rating': 4.5,
#   'reference': 'ChIJT_pel-luDogRSOjE3Yhx7Ws',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 250},
#  'Arts District Brewing Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '828 Traction Ave, Los Angeles, CA 90013, United States',
#   'geometry': {'location': {'lat': 34.0447139, 'lng': -118.2352867},
#    'viewport': {'northeast': {'lat': 34.04611552989272,
#      'lng': -118.2338894201073},
#     'southwest': {'lat': 34.04341587010727, 'lng': -118.2365890798927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Arts District Brewing Company',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3837,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113439777080755549653">Arts District Brewing</a>'],
#     'photo_reference': 'ATtYBwLnAecXXRjeD04HVE9vBDyIz3RKkpAkpow50Y1ac_F0XCTbEF4oTg1LEaeC0MrOK_0nG9VX9gVxkNu2l8cVmtz9jy2vVmcnR92IxqLtQ8ANhMLEahr0rKbACDTrV7TOnzpJXTdx736ynB3dYJZgs3BArQTx2xnVXTU7i3enAuxs5CVq',
#     'width': 5371}],
#   'place_id': 'ChIJbxSpVTnGwoARTMstXgkwO8o',
#   'plus_code': {'compound_code': '2QV7+VV Los Angeles, California',
#    'global_code': '85632QV7+VV'},
#   'price_level': 2,
#   'rating': 4.5,
#   'reference': 'ChIJbxSpVTnGwoARTMstXgkwO8o',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 2691},
#  'Arundel Cellars & Brewing Co': {'business_status': 'OPERATIONAL',
#   'formatted_address': '11727 E Main St, North East, PA 16428, United States',
#   'geometry': {'location': {'lat': 42.2246558, 'lng': -79.8046777},
#    'viewport': {'northeast': {'lat': 42.22626367989272,
#      'lng': -79.80348252010728},
#     'southwest': {'lat': 42.22356402010728, 'lng': -79.80618217989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Arundel Cellars & Brewing Co',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1365,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111738249951675958943">A Google User</a>'],
#     'photo_reference': 'ATtYBwI1YDU1crlOQl1mCckpD634QaVmEDydEeM1E1IxYe3qg2YixJh8hUFT9LLDkBPGtJwPGIR1wJWGobSlx30Zf0rY2KnMBhzvyVCLb9EPFxoR3Wts7dIomGjr3ZfFHaYNYCAuq10Fvj3DdD-fVJBkLCHWOi1k2ArSi82m_7-BaeSqSu9A',
#     'width': 2048}],
#   'place_id': 'ChIJ02EhWCFmLYgRN9AgczdrrQY',
#   'plus_code': {'compound_code': '65FW+V4 North East, Pennsylvania',
#    'global_code': '87J265FW+V4'},
#   'rating': 4.7,
#   'reference': 'ChIJ02EhWCFmLYgRN9AgczdrrQY',
#   'types': ['tourist_attraction',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 183},
#  'Ascendant Beer Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '412 NW 5th Ave, Portland, OR 97209, United States',
#   'geometry': {'location': {'lat': 45.526194, 'lng': -122.675234},
#    'viewport': {'northeast': {'lat': 45.52752887989272,
#      'lng': -122.6740107701073},
#     'southwest': {'lat': 45.52482922010727, 'lng': -122.6767104298927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Ascendant Beer Company',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2741,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101053391647240551448">PINTS</a>'],
#     'photo_reference': 'ATtYBwITN4ZzXhHkYKxE-OtSTEPpZhHUNxd5EE8bgfkNbhWRdE6IibUYHQSU7sK6Ay_XmH3azIXDf8HKr3EMY1saOi38glIF4J-f1C1GKL-Iz7UvojSTrn7kwUyTxK9hOyarpAgkdYDh0Kpi5KWc2NK3dM9pU95xKcurDDFJxBczmJgCBcvt',
#     'width': 3904}],
#   'place_id': 'ChIJN8GBZQAKlVQRElRNnQZldE4',
# ...
#   'geometry': {'location': {'lat': 38.693897, 'lng': -120.814583},
#    'viewport': {'northeast': {'lat': 38.69535957989272,
#      'lng': -120.8133651701073},
#     'southwest': {'lat': 38.69265992010728, 'lng': -120.8160648298927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Solid Ground Brewing',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3648,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111927215927874216988">Jim Heston</a>'],
#     'photo_reference': 'ATtYBwKfdTXhc_mtQzQ5gAYxkc_XyDmwt_BWi6R0qjJutTn_9T7KzYh-7m0OgK8EFDK-2ryCD77VWLCRlvkz6hST4r-3eN6A2U9-s48Rb8odOyblmfxclmvAWPkPtJD5NmIPXb_-z3-ef-jZgA71mq_OoZL3HTyLfcHNPN6hwifF7biDvabv',
#     'width': 5472}],
#   'place_id': 'ChIJo_LAEvJZmoARuO7g0v13nRQ',
#   'plus_code': {'compound_code': 'M5VP+H5 Diamond Springs, California',
#    'global_code': '84CXM5VP+H5'},
#   'rating': 4.5,
#   'reference': 'ChIJo_LAEvJZmoARuO7g0v13nRQ',
#   'types': ['bar',
#    'liquor_store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 204},
#  'Something Wicked Brewing Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '34 Broadway, Hanover, PA 17325, United States',
#   'geometry': {'location': {'lat': 39.8011512, 'lng': -76.98301769999999},
#    'viewport': {'northeast': {'lat': 39.80234672989272,
#      'lng': -76.98149607010727},
#     'southwest': {'lat': 39.79964707010728, 'lng': -76.98419572989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Something Wicked Brewing Company',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 540,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116944654104836262030">Something Wicked Brewing</a>'],
#     'photo_reference': 'ATtYBwKJwWnJC7Hewr9yFiUEBkYYavYdf9yWZTqWvGR-BmSKP0B2aEqsG7cNWxqG3sCvHVJrRG3jMKMywOjivKnwJ3Cd_6_l98xlvf-MvQq6q0fm3p0-7TMvvN7W8889IMs_HceanD7Rlt5shVYFvbI4CoBGpR-9ig_YqlLZxm4bFfc3ez6g',
#     'width': 960}],
#   'place_id': 'ChIJ6fox6D5ayIkR3De4hn0vmfw',
#   'plus_code': {'compound_code': 'R228+FQ Hanover, Pennsylvania',
#    'global_code': '87F5R228+FQ'},
#   'rating': 4.6,
#   'reference': 'ChIJ6fox6D5ayIkR3De4hn0vmfw',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 71},
#  'Somewhere In Particular Brewing': {'business_status': 'OPERATIONAL',
#   'formatted_address': '5053 Dierker Rd, Columbus, OH 43220, United States',
#   'geometry': {'location': {'lat': 40.06193529999999,
#     'lng': -83.07543880000001},
#    'viewport': {'northeast': {'lat': 40.06327852989272,
#      'lng': -83.07390182010728},
#     'southwest': {'lat': 40.06057887010727, 'lng': -83.07660147989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Somewhere In Particular Brewing',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107930119957243723226">Jessica Roberts</a>'],
#     'photo_reference': 'ATtYBwI7-Xq7oRDkXP3u8LDpB7RVlb5_b6b0HNGGC9-FCi6sprGJD7tlMrllaBzRh5rKcIpvFkMkpxx1vo8_fSZctRmT0-jcrVQBF0OxxkJGNRaDhaeDOulQz_pIBhKTtIVxhUXSn0zUHLHqzXL52MGJQdYof0lTmU8hfORklD_mv-jGHzH2',
#     'width': 4032}],
#   'place_id': 'ChIJISNP_W-NOIgROwVCLvruOJg',
#   'plus_code': {'compound_code': '3W6F+QR Columbus, Ohio',
#    'global_code': '86GR3W6F+QR'},
#   'rating': 4.7,
#   'reference': 'ChIJISNP_W-NOIgROwVCLvruOJg',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 201},
#  'Sonoma Grille': {'business_status': 'OPERATIONAL',
#   'formatted_address': '200 Thiells Mt Ivy Rd, Thiells, NY 10984, United States',
#   'geometry': {'location': {'lat': 41.2008218, 'lng': -74.0323532},
#    'viewport': {'northeast': {'lat': 41.20207432989272,
#      'lng': -74.03091782010729},
#     'southwest': {'lat': 41.19937467010728, 'lng': -74.03361747989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Sonoma Grille',
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109598451256104674326">Barbara Gillick</a>'],
#     'photo_reference': 'ATtYBwKk2ZpNMvAcwfOcEl_M6vMdLzBsVpl5MmdlluLNiwLd4z5YyYsmsWJWrTT0fiMktflY_YKtVxS44uJ9NCrEJBABLuULheFj10ER0xQahgeT_Bd8ZNSKaneX1rxc0GtlsPe6sncJo6iNBDsIlsjiAw3yLssJCH5zMkso5XHWoy9pRMrc',
#     'width': 4032}],
#   'place_id': 'ChIJqydI4avEwokR2uNNvbp1y38',
#   'plus_code': {'compound_code': '6X29+83 Thiells, New York',
#    'global_code': '87H76X29+83'},
#   'price_level': 2,
#   'rating': 4.2,
#   'reference': 'ChIJqydI4avEwokR2uNNvbp1y38',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 88},
#  'Sophisticated Hound Brewing Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '833 Mercer St, Princeton, WV 24740, United States',
#   'geometry': {'location': {'lat': 37.369438, 'lng': -81.0940925},
#    'viewport': {'northeast': {'lat': 37.37086667989271,
#      'lng': -81.09275082010727},
#     'southwest': {'lat': 37.36816702010727, 'lng': -81.09545047989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#   'name': 'Sophisticated Hound Brewing Company',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3036,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117075992597958118734">Dave Webb</a>'],
#     'photo_reference': 'ATtYBwJvilxSRE8UniCB9RYhYjvC5Jp78DdZtWivKYQChdRET6JkNKWYbhTdbt7mHx5Ae9w9UfzKxSqCZ8CPDFV0YXcMDRDlYSunek9HYNJkF7uLyccpJrfeBc24c6hPguuPNDmbFoDTo3LPJpTS0uVhAIe-j7aW2tFgmwYMk9M98zm2heZz',
#     'width': 4048}],
#   'place_id': 'ChIJLYhxaJBrTogRuTlXeRMpXCQ',
#   'plus_code': {'compound_code': '9W94+Q9 Princeton, West Virginia',
#    'global_code': '869W9W94+Q9'},
#   'price_level': 2,
#   'rating': 4.7,
#   'reference': 'ChIJLYhxaJBrTogRuTlXeRMpXCQ',
#   'types': ['bar', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 107},
#  'Souris River Brewing': {'business_status': 'OPERATIONAL',
#   'formatted_address': '32 3rd St NE, Minot, ND 58703, United States',
#   'geometry': {'location': {'lat': 48.2375569, 'lng': -101.288289},
#    'viewport': {'northeast': {'lat': 48.23890347989272,
#      'lng': -101.2870473201073},
#     'southwest': {'lat': 48.23620382010728, 'lng': -101.2897469798927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Souris River Brewing',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111064906778246108980">Eric Pearson</a>'],
#     'photo_reference': 'ATtYBwKjgHlxhszbAs_6MuagqzkD-je9iCXKSHqLAB8ogYwm0Ern6P_docXF3-q0EoWkJihijPcGhcn_vN3iiLyRyrXDXFMWbLliuLq5qsgxu1sfrrx5YEi3tnqVOuVS28C6x8v3Gzh-294Ry9Q8gd_BKz3RSyynRZ5rxVKpoLHNarbCOrID',
#     'width': 4032}],
#   'place_id': 'ChIJqzD7Phsq31IR9IPE4r-Ktk4',
#   'plus_code': {'compound_code': '6PQ6+2M Minot, North Dakota',
#    'global_code': '85WW6PQ6+2M'},
#   'rating': 4.4,
#   'reference': 'ChIJqzD7Phsq31IR9IPE4r-Ktk4',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 167},
#  'South Bend Brew Werks': {'business_status': 'OPERATIONAL',
#   'formatted_address': '216 S Michigan St, South Bend, IN 46601, United States',
#   'geometry': {'location': {'lat': 41.6744361, 'lng': -86.2500659},
#    'viewport': {'northeast': {'lat': 41.67578447989272,
#      'lng': -86.24883867010728},
#     'southwest': {'lat': 41.67308482010728, 'lng': -86.25153832989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'South Bend Brew Werks',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1536,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114861019559527278454">South Bend Brew Werks</a>'],
#     'photo_reference': 'ATtYBwK1uhvvzr7kYnEvOUuQzweRYAUiEk8GhVLeCm5wbfBSc-yyxKjP6ClkXTMeCikkz_pw3NiSbYiXzHr0JjG2ookJma67jgMgyXFa8v7x3z91roQ0ngoI9ZIJLuMj7XEqmDmvCQNoxgShHezbSauQlwk5rQy5lqm1Py2lFS-telonbC20',
#     'width': 2048}],
#   'place_id': 'ChIJb29uXDHNFogR6ClwKgUCbrc',
#   'plus_code': {'compound_code': 'MPFX+QX South Bend, Indiana',
#    'global_code': '86HMMPFX+QX'},
#   'rating': 4.3,
#   'reference': 'ChIJb29uXDHNFogR6ClwKgUCbrc',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 257},
#  'South Cypress Brewing': {'business_status': 'OPERATIONAL',
#   'formatted_address': '895 Wiggins Pass Rd, Naples, FL 34110, United States',
#   'geometry': {'location': {'lat': 26.2948608, 'lng': -81.80294289999999},
#    'viewport': {'northeast': {'lat': 26.29613112989272,
#      'lng': -81.80157432010728},
#     'southwest': {'lat': 26.29343147010728, 'lng': -81.80427397989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'South Cypress Brewing',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101832352442529697429">A Google User</a>'],
#     'photo_reference': 'ATtYBwKYlV3VBeOp96F9z4lNudU_1DyxgSlkiL8XGqTwWgX88AwUAez2kBAyc3mzml1-2AFyuOMaszS2rU4TtZTvXYdC0LpXjSjwU1B74YXAF-FN7xlWSJ5-AOn-CBj-TIzEBOWAayVLK0ZjvsgqnWSEkbejO8zcCfYe_j480OIgPQQ8f_A',
#     'width': 3024}],
#   'place_id': 'ChIJh4M2_TgZ24gRoWPY5iSlfCI',
#   'plus_code': {'compound_code': '75VW+WR Naples, Florida',
#    'global_code': '76RW75VW+WR'},
#   'rating': 4.6,
#   'reference': 'ChIJh4M2_TgZ24gRoWPY5iSlfCI',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 22},
#  'South Haven Brewpub': {'business_status': 'OPERATIONAL',
#   'formatted_address': '515 Williams St, South Haven, MI 49090, United States',
#   'geometry': {'location': {'lat': 42.4047469, 'lng': -86.27442339999999},
#    'viewport': {'northeast': {'lat': 42.40601217989271,
#      'lng': -86.27301232010727},
#     'southwest': {'lat': 42.40331252010727, 'lng': -86.27571197989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'South Haven Brewpub',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 540,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109682168029144209859">Ballock&#39;s Bar &amp; Grill</a>'],
#     'photo_reference': 'ATtYBwIsRyi8FosPK6KbZOvenDFcDfmwadZhnpKpbO9qoFIjTfMmimtcgIQnO25XEV_MaqLHINxyG0OnN76ACHG1oruTx7JWqz_Kb-5q7jx_qxOV3-XFoFNYTuVVH_tIC666wk7EfzxKC0JCmzwVU43pZpzznjJFx9CKaTnU-8x_KdQy8mt2',
#     'width': 960}],
#   'place_id': 'ChIJvfGBVaKsEIgR07T4_B2w9qQ',
#   'plus_code': {'compound_code': 'CP3G+V6 South Haven, Michigan',
#    'global_code': '86JMCP3G+V6'},
#   'price_level': 2,
#   'rating': 4,
#   'reference': 'ChIJvfGBVaKsEIgR07T4_B2w9qQ',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 220},
#  'South Park Brewing': {'business_status': 'OPERATIONAL',
#   'formatted_address': '297 1/2 US Hwy 285, Fairplay, CO 80440, United States',
#   'geometry': {'location': {'lat': 39.2203363, 'lng': -105.9926954},
#    'viewport': {'northeast': {'lat': 39.22169972989273,
#      'lng': -105.9914960701073},
#     'southwest': {'lat': 39.21900007010728, 'lng': -105.9941957298927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'South Park Brewing',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1629,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102558716208033671399">South Park Brewing</a>'],
#     'photo_reference': 'ATtYBwJ7w1UcJlOwGaOFkeN2sB7fsktszH1q8t6nC8kFwoq0jM1ai6aMpu7QrIlnvRdKrOGYD65mzUGLNpPuIHkwUqOMfDB1odTm4-qGKY4d7joPWfdkigF1WRfHrUresv1EeXD_vvvGmTqgTzzfEAzhBGMIsaD1P-wGXxuozwToYVyI5HSu',
#     'width': 2048}],
#   'place_id': 'ChIJV9XEfmroaocRZ30CB8vtCP0',
#   'plus_code': {'compound_code': '62C4+4W Fairplay, Colorado',
#    'global_code': '85FP62C4+4W'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJV9XEfmroaocRZ30CB8vtCP0',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 312},
#  'Fiction Beer Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '7101 E Colfax Ave, Denver, CO 80220, United States',
#   'geometry': {'location': {'lat': 39.7403778, 'lng': -104.9056917},
#    'viewport': {'northeast': {'lat': 39.74164637989272,
#      'lng': -104.9043418201073},
#     'southwest': {'lat': 39.73894672010727, 'lng': -104.9070414798927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Fiction Beer Company',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2952,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108188421500577344238">Barry Walter, Jr</a>'],
#     'photo_reference': 'ATtYBwJCpSKEVXutU2Lp43FMFwuPncMeGDqMNeVtEHymVoe3omrgQ1Ngg9cyB4iA9SMnJHscwPGs_acyvslxcuXpgaP-uE815x9lO_FNV52iaiXzraE9cYM-EieZs5oQfEXeUhGCvwk94PXKx3fyknqLVmaQ_Uchy2mqm36pp8964GCW9GY4',
#     'width': 5248}],
#   'place_id': 'ChIJ70rZRnB8bIcRatf_Jil0-VE',
#   'plus_code': {'compound_code': 'P3RV+5P Denver, Colorado',
#    'global_code': '85FQP3RV+5P'},
#   'price_level': 1,
#   'rating': 4.7,
#   'reference': 'ChIJ70rZRnB8bIcRatf_Jil0-VE',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 265},
#  'Urban South Brewery': {'business_status': 'OPERATIONAL',
#   'formatted_address': '1645 Tchoupitoulas St, New Orleans, LA 70130, United States',
#   'geometry': {'location': {'lat': 29.92975199999999,
#     'lng': -90.06702299999999},
#    'viewport': {'northeast': {'lat': 29.93109612989273,
#      'lng': -90.06540457010726},
#     'southwest': {'lat': 29.92839647010728, 'lng': -90.06810422989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Urban South Brewery',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3456,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115619511241941420061">Triskell</a>'],
#     'photo_reference': 'ATtYBwJVDjzuWRnFIth04i98yKHRySmULy2nfuOc0au87BGdkrnMsO9aAON4lepWZe0oQj5gQRYT7NQ-cPXPueI6dix6u1tYI8DkE0KxhYf3vCtemRJPtP3fvwD3l2Y4pv8SEb-MzQ5eTCWtRbLVC8aI2jtxL140gIjRu66vqYcm19p9Aur7',
#     'width': 4608}],
#   'place_id': 'ChIJda7LEX2mIIYR8db5ZOZsaj0',
#   'plus_code': {'compound_code': 'WWHM+W5 New Orleans, Louisiana',
#    'global_code': '76XFWWHM+W5'},
#   'rating': 4.7,
#   'reference': 'ChIJda7LEX2mIIYR8db5ZOZsaj0',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 384},
#  'Black Project Spontaneous & Wild Ales': {'business_status': 'OPERATIONAL',
#   'formatted_address': '1290 S Broadway A51, Denver, CO 80210, United States',
#   'geometry': {'location': {'lat': 39.6933906, 'lng': -104.9872738},
#    'viewport': {'northeast': {'lat': 39.69474157989272,
#      'lng': -104.9859854701073},
#     'southwest': {'lat': 39.69204192010728, 'lng': -104.9886851298927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Black Project Spontaneous & Wild Ales',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 326,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111946968477953026990">A Google User</a>'],
#     'photo_reference': 'ATtYBwJj3MIkXyI08AoxNWeVwatIjg1lOY99RveysVJ0dh0F_FTk1kUBCk2Dzx91gjaIpFRlvUlVWNLlJ9TG-ttfK337NienRT9nitxbK0lVxmwgMuMClv7-DjJuKVCQ3VPvsmTT0mLyNX-508k-D9BJwVSR8C3-cjdzSucvfX1CtIBEmZB3',
#     'width': 579}],
#   'place_id': 'ChIJEzIcZqt_bIcRcFdcuqR84tI',
#   'plus_code': {'compound_code': 'M2V7+93 Denver, Colorado',
#    'global_code': '85FQM2V7+93'},
#   'rating': 4.7,
#   'reference': 'ChIJEzIcZqt_bIcRcFdcuqR84tI',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 228},
#  ...}

# %% [markdown]
# # Creating Reproducible Loops to clean the data and convert it to a DataFrame

# %% [markdown]
# The main issue that we found was that there was not just a one to one ratio of results to query. The results were captured as dictionaries and organized within a list. This means we would have to find a way to pull out not only one single dictionary from list, but make sure that it even matches the original query.

# %%
import json
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/MyDrive/Stuff For Project Wynton/Copy of brewery_master.csv', 'r') as f:
    master = pd.read_csv(f)
    brewtable = pd.DataFrame(master)

# %%
with open('/content/drive/MyDrive/Stuff For Project Wynton/google_queries2.json', 'r') as f:
    queries = json.load(f)

# %% [markdown]
# As demonstrated in the code block below, the json format of the Google Places API is rather staright forward. For the dataset we are trying to form, we are only interested in the following tags:
# 1. name
# 2. formatted_address
# 3. location
# 4. rating
# 5. user_ratings_total

# %%
queries
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# In order to process the specific results, we need to pull out the result list specifically. In my code, I changed the value of each query key to be just the value of the result key in the Google Places json data.

# %%
for each in queries:
    queries[each] = queries[each]['results']

# %% [markdown]
# Through (very tedious) line by line, brute-force inspection of many of the key-value pairs in the query dictionary (length 7794), we were able to inference that any result list that had a length of one found within the dictionary was almost always an exact match. Furthermore, there are queries that return no data at all. In order to further my investigation and formulate a reproducible strategy, we seperated the NULL queries and the queries with exactly one result.
# This produces roughly 6000 - 6500 separate key-values. Then, we were only left with queries that had multiple results to run through.

# %%
keys = list(queries.keys())
one = dict()
greater = dict()
other = dict()
for j in range(len(keys)):
  if len(queries[keys[j]]) == 1:
    one[keys[j]] = queries[keys[j]]
  elif len(queries[keys[j]]) > 1:
    greater[keys[j]] = queries[keys[j]]
  else:
    other[keys[j]] = queries[keys[j]]

#extract the result from the list and replace the list of length 1 with element 0 (key = master list query term, 
#value = json data on matching place)
for o in one:
    one[o] = one[o][0]

#Once the remaining ~1000 remain, extract the Google Places data from
#the 'results' list that matches the name from the master list, or if the brewery
#name from the master list is in the full brewery name
for v in greater:
    for i in greater[v]:
        if v.lower() == i['name'].lower() or v in i['name']:
            greater[v] = i

greater_delete = dict()
greater_keep = dict()

for a in greater:

    if type(greater[a]) is list:
        
        #If the value of a query-key is still
        #a list, then seperate these unprocessed values
        greater_delete[a] = greater[a]
        
    else:
        #fully processed and cleaned     
        greater_keep[a] = greater[a]

#Merge the three dictionaries back together         
one.update(other)
one.update(greater_keep)

#Make the remaining unprocessed data into empty lists
#empty list = no results/could not be processed cleanly
for a in greater_delete:
    greater_delete[a] = list()

one.update(greater_delete)

print(len(one))

#write out to keep a permanent copy of the data that will be processed
#into a DataFrame/.csv file
with open('/content/drive/MyDrive/Stuff For Project Wynton/full_table.json','w') as f:
    json.dump(one, f)
# Out:
# 7794

# %%
with open('/content/drive/MyDrive/Stuff For Project Wynton/full_table.json','r') as f:
    full = json.load(f)

# %%
#The json format of the cleaned data
full
# Out:
# {'122 West Brewing Co': {'business_status': 'OPERATIONAL',
#   'formatted_address': '2416 Meridian St, Bellingham, WA 98225, United States',
#   'geometry': {'location': {'lat': 48.7625675, 'lng': -122.4858342},
#    'viewport': {'northeast': {'lat': 48.76391782989273,
#      'lng': -122.4846295701073},
#     'southwest': {'lat': 48.76121817010728, 'lng': -122.4873292298928}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': '122 West Brewing Co.',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1440,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115258052358653244868">A Google User</a>'],
#     'photo_reference': 'ATtYBwIFnZtl7ilvvIsEeuhqMChGy5yWqUGlfjc1G5Az1wAoDLXSSmvoI_iDlUnH1d-cWrY9kql8yepNi-zumHLAwm-5yGyhhDPPEIJO20k4-qFaqE1ZQJpNkmIa4f8gWlUKzjuSBBjtvAd1s7M-CfvXALOiltaTwHB-xQOmBwXNuO-nSlPF',
#     'width': 1440}],
#   'place_id': 'ChIJU24foIijhVQRt25PZ8UrOBk',
#   'plus_code': {'compound_code': 'QG77+2M Bellingham, Washington',
#    'global_code': '84WVQG77+2M'},
#   'rating': 4.6,
#   'reference': 'ChIJU24foIijhVQRt25PZ8UrOBk',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 62},
#  '12Degree Brewing': {'business_status': 'OPERATIONAL',
#   'formatted_address': '820 Main St, Louisville, CO 80027, United States',
#   'geometry': {'location': {'lat': 39.9782385, 'lng': -105.1319916},
#    'viewport': {'northeast': {'lat': 39.97958907989272,
#      'lng': -105.1307101201073},
#     'southwest': {'lat': 39.97688942010728, 'lng': -105.1334097798927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': '12Degree Brewing',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2237,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102700741848758923705">Twelve Degree Brewing</a>'],
#     'photo_reference': 'ATtYBwLYHtVZuNEtKqxfvPbtt17zunf6hMxK-r_xR5YXgw3_7hbwa4IQp_59tZyP6HVFT_ZFRYySTH8GCXzxDkGzH01Q4099R6_HOfSQHXw0K1-PApeRF_ryiR9HoQwpJr3qFiYm8ST6Jgqv1GrK6C0uDX1PuAm5pvycP6OItodICmjuPOyz',
#     'width': 2237}],
#   'place_id': 'ChIJV5-01V3za4cRHErorPGilxs',
#   'plus_code': {'compound_code': 'XVH9+76 Louisville, Colorado',
#    'global_code': '85FPXVH9+76'},
#   'price_level': 2,
#   'rating': 4.7,
#   'reference': 'ChIJV5-01V3za4cRHErorPGilxs',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 231},
#  '15 24 Brew House': {'business_status': 'OPERATIONAL',
#   'formatted_address': '420 Lincoln Ave, Clay Center, KS 67432, United States',
#   'geometry': {'location': {'lat': 39.3761435, 'lng': -97.1275175},
#    'viewport': {'northeast': {'lat': 39.37755837989272,
#      'lng': -97.12616702010729},
#     'southwest': {'lat': 39.37485872010727, 'lng': -97.12886667989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': '15-24 Brew House',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102794122164029792267">Morgan Sharp</a>'],
#     'photo_reference': 'ATtYBwLcHRS4X6ANRZXvEusRVIWlOfTCaTspVaVkESASGfd9Yvk2Notl_ugV7U_dHkiZFc8feCc0OXAnXnq3ps498wQYl-EJy8G2nHzaqF6VXfyo1UZXAh1j79x2-z3X-CIdbJnedgzrTiPuMCvzT3KWFGuIA3rbj4SsMM2ou3zeOP5ZlD82',
#     'width': 4032}],
#   'place_id': 'ChIJx9ohZWcLvYcR1aoQkLFrd8g',
#   'plus_code': {'compound_code': '9VGC+FX Clay Center, Kansas',
#    'global_code': '86F49VGC+FX'},
#   'rating': 4.6,
#   'reference': 'ChIJx9ohZWcLvYcR1aoQkLFrd8g',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 130},
#  '16 Stone Brewpub': {'business_status': 'OPERATIONAL',
#   'formatted_address': '9542 Main St, Holland Patent, NY 13354, United States',
#   'geometry': {'location': {'lat': 43.2418785, 'lng': -75.25634},
#    'viewport': {'northeast': {'lat': 43.24330112989272,
#      'lng': -75.25506852010727},
#     'southwest': {'lat': 43.24060147010728, 'lng': -75.25776817989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': '16 Stone Brewpub',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1536,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108049004380651177051">A Google User</a>'],
#     'photo_reference': 'ATtYBwK65naD7EVNUIjV6_vLvSyHq_kCN_ChjdkoS8zcws-1oBUW2nVrpEb5mRrAHSNZQTvFcG-SpWkduPDA71Jc5uxMeuS_bygwO0q6xtd9ehbQh9g_yiEIW1K6rOvule2Xsf8sBeoHQqVVon05ATSXkE01SqjkoEr35XxijLlANFauj48T',
#     'width': 2048}],
#   'place_id': 'ChIJ8Rn1hnA82YkRpnCWF83_Gww',
#   'plus_code': {'compound_code': '6PRV+QF Holland Patent, New York',
#    'global_code': '87M66PRV+QF'},
#   'rating': 4.6,
#   'reference': 'ChIJ8Rn1hnA82YkRpnCWF83_Gww',
#   'types': ['bar', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 71},
#  '1718 Ocracoke Brewing': {'business_status': 'OPERATIONAL',
#   'formatted_address': '1129 Irvin Garrish Hwy, Ocracoke, NC 27960, United States',
#   'geometry': {'location': {'lat': 35.107474, 'lng': -75.971818},
#    'viewport': {'northeast': {'lat': 35.10865152989272,
#      'lng': -75.97054437010728},
#     'southwest': {'lat': 35.10595187010728, 'lng': -75.97324402989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': '1718 Brewing Ocracoke',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103873422033864105645">A Google User</a>'],
#     'photo_reference': 'ATtYBwIWbDnguf1bMHR7S4YXImycztYaZpHZo5a6e6Vc6F_riXrbS70B9v7sehocQqoHEXYn3NZGm-ijYky_tEEUxZd1J-A0_09VlupfeCRtibzhfdisKQwWyerLzj2nLE6WI2lEiT1B60vTC7hZHASo7TxnzHCD2jD72eWALyTSb2X1i9_A',
#     'width': 4032}],
#   'place_id': 'ChIJXcSUGb3YpYkRU1HgPbZ5l8I',
#   'plus_code': {'compound_code': '424H+X7 Ocracoke, North Carolina',
#    'global_code': '8776424H+X7'},
#   'rating': 4.7,
#   'reference': 'ChIJXcSUGb3YpYkRU1HgPbZ5l8I',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 214},
#  '1787 Brewing Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '43 S Fourth St, Hamburg, PA 19526, United States',
#   'geometry': {'location': {'lat': 40.554327, 'lng': -75.98189099999999},
#    'viewport': {'northeast': {'lat': 40.55566147989272,
#      'lng': -75.98060627010727},
#     'southwest': {'lat': 40.55296182010728, 'lng': -75.98330592989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': '1787 Brewing Company',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113035195714389391764">Dana Foust</a>'],
#     'photo_reference': 'ATtYBwKgbJYVhaj-TiJJomSvek7Wp6d_WyTNiYLLpoFP1UnILOKZgysYCoI_YOA65v_qpB7nuAQcYWAY7cmydK4fbAeS_EYluV57srIUjJQWfyYa6ZpwuCAvfiLqdbTS4yV-DGgqT_Hv_liI6pSi3gVm5ORDOfz7XQF0wh805DoUVM6irWyw',
#     'width': 4032}],
#   'place_id': 'ChIJm-iMT2XbxYkRBa8yUr2NCPM',
#   'plus_code': {'compound_code': 'H239+P6 Hamburg, Pennsylvania',
#    'global_code': '87G6H239+P6'},
#   'price_level': 2,
#   'rating': 4.5,
#   'reference': 'ChIJm-iMT2XbxYkRBa8yUr2NCPM',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 518},
#  '1849 Brewing Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '468 Sutton Way, Grass Valley, CA 95945, United States',
#   'geometry': {'location': {'lat': 39.2324126, 'lng': -121.0368826},
#    'viewport': {'northeast': {'lat': 39.23382222989272,
#      'lng': -121.0351654201073},
#     'southwest': {'lat': 39.23112257010728, 'lng': -121.0378650798927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': '1849 Brewing Company',
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104449113900710011219">Matt O</a>'],
#     'photo_reference': 'ATtYBwIM43-hvygZdo1_HowGib_pTbULEIWS081ynqqEvbyOpWp6PVz74jox4rW7rDwx8xtVlTAIe9WhqE3mCVJCrW3X53dSJ2AyRyGWAu_nNVsWG7a3ijTDZ1QH0ELCXqktP-SDRiG9xQKrIUtvhg7I2Q52zjHXhbQCq1pr-v7xlOyA98By',
#     'width': 4032}],
#   'place_id': 'ChIJoUtya1Bxm4ARGG8BoeoOHEE',
#   'plus_code': {'compound_code': '6XJ7+X6 Grass Valley, California',
#    'global_code': '84FW6XJ7+X6'},
#   'rating': 3.9,
#   'reference': 'ChIJoUtya1Bxm4ARGG8BoeoOHEE',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 131},
#  '18th Ward Brewing Co': {'business_status': 'OPERATIONAL',
#   'formatted_address': '300 Richardson St, Brooklyn, NY 11222, United States',
#   'geometry': {'location': {'lat': 40.7195918, 'lng': -73.93958219999999},
#    'viewport': {'northeast': {'lat': 40.72099027989272,
#      'lng': -73.93825847010727},
#     'southwest': {'lat': 40.71829062010728, 'lng': -73.9409581298927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': '18th Ward Brewing',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 640,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113955271760348556882">A Google User</a>'],
#     'photo_reference': 'ATtYBwLCwwtg7vJjOenihQ_miu5EeMJY2pCJVyeVHnS_z0Xbuia0ut3m9vzE4j06ttp0Z8h8EwHTZDyeLa9fdNG7OTOCfVkrYCdm7qh2pVqQzUVNonAiUMSdBTNiiAbK8RMG03LzaKoyCRJDZ5K0R4SWIQ4xgesYrvczCslStzuHt_u9104U',
#     'width': 480}],
#   'place_id': 'ChIJAWcAJyJZwokRLVQFkjOVMKg',
#   'plus_code': {'compound_code': 'P396+R5 Brooklyn, New York',
#    'global_code': '87G8P396+R5'},
#   'rating': 4.5,
#   'reference': 'ChIJAWcAJyJZwokRLVQFkjOVMKg',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 37},
#  '2 Feet Brewing Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '80 Columbia St, Bangor, ME 04401, United States',
#   'geometry': {'location': {'lat': 44.8002365, 'lng': -68.7727324},
#    'viewport': {'northeast': {'lat': 44.80161157989273,
#      'lng': -68.77146532010728},
#     'southwest': {'lat': 44.79891192010728, 'lng': -68.77416497989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': '2 Feet Brewing Co.',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2340,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102764704132906514142">2 Feet Brewing Co.</a>'],
#     'photo_reference': 'ATtYBwKsnGpPzY_uWVwpODU36TVxhUPrzcHkx5n9y1aSuLAr6AaDbaGDwkAF6D7A-NVMQrWsT_BTH_x_AIEOKzm7Ka5JEIAr8-VBbjXwJhifoHMltEMD40ufhCXtoTTKrBpeEU4779TH35LShNr3JA6kodmfL2J64HKqkOOYho2OPB4bptf0',
#     'width': 4160}],
#   'place_id': 'ChIJx4BBvkRLrkwR2Dp4_FtNTsA',
#   'plus_code': {'compound_code': 'R62G+3W Bangor, Maine',
#    'global_code': '87PHR62G+3W'},
#   'price_level': 1,
#   'rating': 4.6,
#   'reference': 'ChIJx4BBvkRLrkwR2Dp4_FtNTsA',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 211},
#  '20 Corners Brewing LLC': {'business_status': 'OPERATIONAL',
#   'formatted_address': '14148 NE 190th St A, Woodinville, WA 98072, United States',
#   'geometry': {'location': {'lat': 47.7678642, 'lng': -122.1517007},
#    'viewport': {'northeast': {'lat': 47.76926852989273,
#      'lng': -122.1502455701073},
#     'southwest': {'lat': 47.76656887010728, 'lng': -122.1529452298927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': '20 Corners Brewing',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101353644465590325234">Dave M</a>'],
#     'photo_reference': 'ATtYBwJKnmWa1UjRke-iT5iTMenMASr4SdUXeGUAwO44J0-VMrptQdLNKKJrq356eXudxDe8DsiGV-x5sAoobxb2d950T8FnnhrutGsugT0nlZPLAUTgjDKlg9m-f5AmqCv51d0h41lDtJ2hJPHeyjR7O8dc5lLUFqHdLcbQ_g6OTFKRafRQ',
#     'width': 4032}],
#   'place_id': 'ChIJbyKhrpkOkFQRLDr58FMt1KQ',
#   'plus_code': {'compound_code': 'QR9X+48 Woodinville, Washington',
#    'global_code': '84VVQR9X+48'},
#   'rating': 4.6,
#   'reference': 'ChIJbyKhrpkOkFQRLDr58FMt1KQ',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 303},
#  '210 Brewing Co': {'business_status': 'OPERATIONAL',
#   'formatted_address': '3438 Stoluckquamish Ln, Arlington, WA 98223, United States',
#   'geometry': {'location': {'lat': 48.2145095, 'lng': -122.1841675},
#    'viewport': {'northeast': {'lat': 48.21565797989272,
#      'lng': -122.1829977201073},
#     'southwest': {'lat': 48.21295832010727, 'lng': -122.1856973798927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': '210 Brewing CO',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109017389229335327462">ron matthews</a>'],
#     'photo_reference': 'ATtYBwLvJdBtWaZXccyRD_Ls56dCMUeSLLyGClYzhvXNYMTLkvzJfYo3mZ6ZzeFtjfZKSV5jy3IIRM7ju5-hUKJYztLByD0kc53RiiE0dyFLdC9dDaBNXVV9Gksbe-8zxRqW3o-uJsgYwSWaskUDfKb4n_QvvMfQEdDaCP5L4GoBG7Pw_l4',
#     'width': 4032}],
#   'place_id': 'ChIJ_2DpLORFhVQR76N7biMnUuI',
#   'plus_code': {'compound_code': '6R78+R8 Arlington, Washington',
#    'global_code': '84WV6R78+R8'},
#   'rating': 3.7,
#   'reference': 'ChIJ_2DpLORFhVQR76N7biMnUuI',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 33},
#  '21st Amendment Brewery Cafe': {'business_status': 'OPERATIONAL',
#   'formatted_address': '563 2nd St, San Francisco, CA 94107, United States',
#   'geometry': {'location': {'lat': 37.7825245, 'lng': -122.3924605},
#    'viewport': {'northeast': {'lat': 37.78378757989272,
#      'lng': -122.3912259201073},
#     'southwest': {'lat': 37.78108792010728, 'lng': -122.3939255798927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': '21st Amendment Brewery & Restaurant',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116556357736267274624">A Google User</a>'],
#     'photo_reference': 'ATtYBwIIQOFWa-Qw4cpfphg-SZ1rfLIS9Boe8cVueC6n4F3ONVdZ72ONWbMPhTL9PUKk7OP-bpQDe93d_jT4Ifxxh4CQS-kDolnETcSWEVAjVgy488R1rI1mtkC9dlQY2k9nG_Hl9KmalJeZY-v418iUisc9PCPbQS4MwYNI5Tp44lPaIFeO',
#     'width': 4032}],
#   'place_id': 'ChIJYwMBJ-l9hYAR66sAdy3sjKQ',
#   'plus_code': {'compound_code': 'QJM5+22 Central Embarcadero Piers Historic District, California',
#    'global_code': '849VQJM5+22'},
#   'price_level': 2,
#   'rating': 4.3,
#   'reference': 'ChIJYwMBJ-l9hYAR66sAdy3sjKQ',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1227},
#  '22 Northmen Brewing Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '6693 County Rd 34 NW building b, Alexandria, MN 56308, United States',
#   'geometry': {'location': {'lat': 45.9606348, 'lng': -95.3945368},
#    'viewport': {'northeast': {'lat': 45.96186342989272,
#      'lng': -95.3935876701073},
#     'southwest': {'lat': 45.95916377010728, 'lng': -95.39628732989274}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': '22 Northmen Brewing Company',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2400,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109751370772069594263">A Google User</a>'],
#     'photo_reference': 'ATtYBwL7NX6n-NqHUkT_IZU1-deaqeSXEepEK37GM_eRsSV5_5C2EPwzh1IrcPq7ZKCAi3VHzmz67dMQNv6otZAdxWH3A-lOUyu1DeMYv3ScKuxD1qjVGn2jddkEqkZOuw0877gR1nDT9C5A-rT_TBoZDwcULcIutX3RCYgaKjKExVtYlxEY',
#     'width': 4267}],
#   'place_id': 'ChIJ5W4R2aQFylIRgt8YDMn1VNA',
#   'plus_code': {'compound_code': 'XJ64+75 Alexandria, Minnesota',
#    'global_code': '86Q6XJ64+75'},
#   'rating': 4.4,
#   'reference': 'ChIJ5W4R2aQFylIRgt8YDMn1VNA',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 71},
#  '23rd Street Brewery': {'business_status': 'OPERATIONAL',
#   'formatted_address': '3512 Clinton Parkway, Lawrence, KS 66047, United States',
#   'geometry': {'location': {'lat': 38.9430353, 'lng': -95.2810567},
#    'viewport': {'northeast': {'lat': 38.94439977989272,
#      'lng': -95.27961317010727},
#     'southwest': {'lat': 38.94170012010728, 'lng': -95.28231282989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': '23rd Street Brewery',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1836,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101547982187272467735">Scott Ellsworth</a>'],
#     'photo_reference': 'ATtYBwLMpPP0JHhe-JHXuseJ1L-0CjPXKnllPbtEY_y1F_ONd1_LgDd9D7eBwLUMn-HyhCkNvf8QYASs4ba9a89jbX4XnM1yy_Ikca14gj27vZ9dTAKS5NQXhBgvKmLt2szsdqaUX48ItL2gaB3mb1-OSEaaPWjJ13Fv0Gkob4RdKiGkexO2',
#     'width': 3264}],
#   'place_id': 'ChIJYfXGXDBpv4cROksVQCJ1eD0',
#   'plus_code': {'compound_code': 'WPV9+6H Lawrence, Kansas',
#    'global_code': '86C6WPV9+6H'},
#   'price_level': 2,
#   'rating': 4.3,
#   'reference': 'ChIJYfXGXDBpv4cROksVQCJ1eD0',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 441},
#  '2nd Story Brewing Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '117 Chestnut St, Philadelphia, PA 19106, United States',
#   'geometry': {'location': {'lat': 39.9484375, 'lng': -75.1435245},
#    'viewport': {'northeast': {'lat': 39.94972592989273,
#      'lng': -75.14217837010727},
#     'southwest': {'lat': 39.94702627010728, 'lng': -75.14487802989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': '2nd Story Brewing',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100450923346831873572">Phil T</a>'],
#     'photo_reference': 'ATtYBwI2TjEDbmBsE8my9AH638iEG42x72n-eEMTyzQor01ocoU1UsP0XJjculG83wHin4RKZqnFU-WMfBrlP8-2p6zOmgsulqVyWrf6goeADC8X_JdhiLUbP2wEv0yV_tYDrjA4MyND2vvJ-xVUc2Lqg1E4fvorJwr8nY2zoQ8Vf2Bklsn6',
#     'width': 4032}],
#   'place_id': 'ChIJNxHEeoXIxokRQZiOyO9TX6k',
#   'plus_code': {'compound_code': 'WVX4+9H Philadelphia, Pennsylvania',
#    'global_code': '87F6WVX4+9H'},
#   'rating': 4.3,
#   'reference': 'ChIJNxHEeoXIxokRQZiOyO9TX6k',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 643},
#  '3 Keys Brewing Company LLC': {'business_status': 'OPERATIONAL',
#   'formatted_address': '2505 Manatee Ave E, Bradenton, FL 34208, United States',
#   'geometry': {'location': {'lat': 27.496807, 'lng': -82.53257699999999},
#    'viewport': {'northeast': {'lat': 27.49792552989272,
#      'lng': -82.53122777010726},
#     'southwest': {'lat': 27.49522587010728, 'lng': -82.53392742989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': '3 Keys Brewing and Eatery',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2269,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106858066979832717849">3 Keys Brewing and Eatery</a>'],
#     'photo_reference': 'ATtYBwInG3qXONdEwKYZLS4jf0TNlRXu-gNqiQRnWQ1LiGpcD8MpVdkTQZEYk8FP95NQkHaYBYzYlklEu2jERx8NDflM-2j4M5O6ClhiP5HkE3pO6CPs5-TI9r-lSCz5AKwpTkaE7tSYzU0w-wNkclMUN0GYtFia3chZIf-qEQtnKC0nMv9l',
#     'width': 4032}],
#   'place_id': 'ChIJm5Y42w49w4gRR9EAaNecD4A',
#   'plus_code': {'compound_code': 'FFW8+PX Bradenton, Florida',
#    'global_code': '76VVFFW8+PX'},
#   'rating': 4.5,
#   'reference': 'ChIJm5Y42w49w4gRR9EAaNecD4A',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 518},
#  '3 Trails Brewing': {'business_status': 'OPERATIONAL',
#   'formatted_address': '111 N Main St, Independence, MO 64050, United States',
#   'geometry': {'location': {'lat': 39.092571, 'lng': -94.41528199999999},
#    'viewport': {'northeast': {'lat': 39.09392622989272,
#      'lng': -94.41412702010727},
#     'southwest': {'lat': 39.09122657010727, 'lng': -94.41682667989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': '3 Trails Brewing',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109752986114941529129">John Sands</a>'],
#     'photo_reference': 'ATtYBwJDx9F2t42daWLvVVkSLbnPgEWJUE-gdgugdbtVvAF-pl7d4V9Bp12ICUMG8V4-az-yImSLl4bx2KmiKxyQK3X9CcFritUInZkOE9p-wC8lrE6unbO4HOaBaGREaqAVOyu5vLS68PM7Zqdb4A3hdR5ZyvwhSzUKFokXJmRvFDSiIba5',
#     'width': 4032}],
#   'place_id': 'ChIJe2hTA7b9wIcRKvUnY1bIkUQ',
#   'plus_code': {'compound_code': '3HVM+2V Independence, Missouri',
#    'global_code': '86F73HVM+2V'},
#   'rating': 4.8,
#   'reference': 'ChIJe2hTA7b9wIcRKvUnY1bIkUQ',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 94},
#  '300 Suns Brewing Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '335 1st Ave, Longmont, CO 80501, United States',
#   'geometry': {'location': {'lat': 40.16, 'lng': -105.1011111},
#    'viewport': {'northeast': {'lat': 40.16146152989271,
#      'lng': -105.0998601201073},
#     'southwest': {'lat': 40.15876187010727, 'lng': -105.1025597798927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': '300 Suns Brewing',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1600,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117469948533094859888">300 Suns Brewing</a>'],
#     'photo_reference': 'ATtYBwKOZweKhxnlAS_bJzIbi4vSPPCGrzBTj92m3Gj-HLoWdsryIdnmgkt9FklkhT1i98pQvj2zGZ3TWQhUw0S0hE56zvBsZMrllxT7c4Z0IGDNB8cFXGhCUUfdR7nEIYb_4Wml99_MlmpygOKooEWDjYf4ynA6fQQ689UIISdJWT6G2nGV',
#     'width': 1600}],
#   'place_id': 'ChIJzTJtH6L5a4cRxe_WXDORfxc',
#   'plus_code': {'compound_code': '5V5X+XH Longmont, Colorado',
#    'global_code': '85GP5V5X+XH'},
#   'rating': 4.7,
#   'reference': 'ChIJzTJtH6L5a4cRxe_WXDORfxc',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 293},
#  '350 Brewing Co': {'business_status': 'OPERATIONAL',
#   'formatted_address': '7144 183rd St, Tinley Park, IL 60477, United States',
#   'geometry': {'location': {'lat': 41.559356, 'lng': -87.7915471},
#    'viewport': {'northeast': {'lat': 41.56062287989273,
#      'lng': -87.79015187010728},
#     'southwest': {'lat': 41.55792322010728, 'lng': -87.79285152989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': '350 Brewing Company',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 539,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101013648177769926596">A Google User</a>'],
#     'photo_reference': 'ATtYBwIEzwSMUhVrKlRJnaNHCJ_ZsetH9AETAtA637yN64kQW8vpDlsILyYfTl9U4lMSwFSGzhuFxnM1oUl6yCDwE45HInjTfw8ZmfdAEoDBLG061qTzuOWSLSoBbhUnMl6v8dNKMRdtP8WHlOJAgk5tYid3YohJx4btePtW1dCbcx6g3Jfj',
#     'width': 720}],
#   'place_id': 'ChIJEVY_afgVDogRo2Fwqitv2JA',
#   'plus_code': {'compound_code': 'H655+P9 Tinley Park, Illinois',
#    'global_code': '86HJH655+P9'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJEVY_afgVDogRo2Fwqitv2JA',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 451},
#  '38 75 Brewing': {'business_status': 'OPERATIONAL',
#   'formatted_address': '2000 Coastal Hwy, Dewey Beach, DE 19971, United States',
#   'geometry': {'location': {'lat': 38.6953767, 'lng': -75.0749172},
#    'viewport': {'northeast': {'lat': 38.69672652989271,
#      'lng': -75.07356737010727},
#     'southwest': {'lat': 38.69402687010727, 'lng': -75.07626702989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': "Gary's Dewey Beach Grill / 38° -75° Brewing",
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1192,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109962893667555417906">Gary&#39;s Dewey Beach Grill</a>'],
#     'photo_reference': 'ATtYBwJ6jgXoR0hDppdda2YwbbTo8CVmPOPo6DGujNfkAQWfahWB5-4fGUxuMWoCeR1cj5OUHuJhYyrqreQZNteOzYsUet8HABvUqMkqPbBkFtlhtdhMCLapG2P28Zfj3s0CPHFnhDo8EkSWhAKJqKsGxlTJTssonPDqXF7UvBrHAlVcKb1M',
#     'width': 2119}],
#   'place_id': 'ChIJuQChEhu2uIkR1gGIjApi3jk',
#   'plus_code': {'compound_code': 'MWWG+52 Dewey Beach, Delaware',
#    'global_code': '87C6MWWG+52'},
#   'rating': 4.2,
#   'reference': 'ChIJuQChEhu2uIkR1gGIjApi3jk',
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 89},
#  '3Halves Brewing Co LLC': {'business_status': 'OPERATIONAL',
#   'formatted_address': '110 E Kansas St, Liberty, MO 64068, United States',
#   'geometry': {'location': {'lat': 39.2461756, 'lng': -94.41895319999999},
#    'viewport': {'northeast': {'lat': 39.24748387989273,
#      'lng': -94.41760287010727},
#     'southwest': {'lat': 39.24478422010728, 'lng': -94.42030252989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': '3Halves Brewing Co.',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1365,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112411940904708738808">A Google User</a>'],
#     'photo_reference': 'ATtYBwIOOTprDJqQJz3nY4iIXRdtkLCQJD1vcmAJG3NEO35TFFa5B7FwONDVrRM-QydJnGFoqxCfoDoxQ8tHn4MBBKS9QmU13_3lX6zrXA6bbB2yNPnWJS2nTpa-51EtDRXqe0tXFealFDAUdVYwXES8gAfHlzZpDZs1kHSDnoMRkuBNmCU',
#     'width': 2048}],
#   'place_id': 'ChIJIa8fzBNVwIcRCGpzBqWD9c8',
#   'plus_code': {'compound_code': '6HWJ+FC Liberty, Missouri',
#    'global_code': '86F76HWJ+FC'},
#   'rating': 4.5,
#   'reference': 'ChIJIa8fzBNVwIcRCGpzBqWD9c8',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 84},
#  '406 Brewing Company': {'business_status': 'CLOSED_PERMANENTLY',
#   'formatted_address': '324 E Main St, Manhattan, MT 59741, United States',
#   'geometry': {'location': {'lat': 45.85452009999999, 'lng': -111.3299358},
#    'viewport': {'northeast': {'lat': 45.85586992989271,
#      'lng': -111.3285859701073},
#     'southwest': {'lat': 45.85317027010727, 'lng': -111.3312856298927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': '406 Brewing Company',
#   'permanently_closed': True,
#   'photos': [{'height': 1365,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109099942077377869807">406 Brewing Company</a>'],
#     'photo_reference': 'ATtYBwJcmJL4YCL6DmMq7rqocoeeoxhkHOiEExuvz2Q7Io49ROiXY1YLQbP2GMW4RqUYPwhU6pFm8aPRQ9lGbJFq2VLfTzal8zkIDNp7xXG625H6L1l3bZStiqAlwosDscTQpyrWb-L7ynEsa2W_vexmmq9SqBfxjzjegjgmWo4KNHEOGFNp',
#     'width': 2048}],
#   'place_id': 'ChIJLZOxdkBERVMRed6lJo_DpQM',
#   'plus_code': {'compound_code': 'VM3C+R2 Manhattan, Montana',
#    'global_code': '85QCVM3C+R2'},
#   'rating': 4.6,
#   'reference': 'ChIJLZOxdkBERVMRed6lJo_DpQM',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 96},
#  '42 North Brewing Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '25 Pine St, East Aurora, NY 14052, United States',
#   'geometry': {'location': {'lat': 42.7685764, 'lng': -78.6080822},
#    'viewport': {'northeast': {'lat': 42.76991377989273,
#      'lng': -78.60663952010728},
#     'southwest': {'lat': 42.76721412010728, 'lng': -78.60933917989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': '42 North Brewing Company',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2048,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102569299245683399020">42 North Brewing Company</a>'],
#     'photo_reference': 'ATtYBwIE2qIUAMfsEGSdQlBhSC2p0z0Ov5udF6fomPBwGxheape9qpRmKzTMFXsXGRTOfBQBUb-8S_Lw7mFE3EM8CWtokvKAsKimSBOQkJuv51TyWrJWSSeG_F4YRO9ksvg6wnCQ0glmNe7CMePwIUkto8hJnpTKHE7X2qBXAGf7fHsVprWF',
#     'width': 1536}],
#   'place_id': 'ChIJ4WOwui2m04kRRtLa-NGmskE',
#   'plus_code': {'compound_code': 'Q99R+CQ East Aurora, New York',
#    'global_code': '87J3Q99R+CQ'},
#   'rating': 4.5,
#   'reference': 'ChIJ4WOwui2m04kRRtLa-NGmskE',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 249},
#  '450 North Brewing Company Simmons Winery': {'business_status': 'OPERATIONAL',
#   'formatted_address': '8111 E 450 N, Columbus, IN 47203, United States',
#   'geometry': {'location': {'lat': 39.2679636, 'lng': -85.8327109},
#    'viewport': {'northeast': {'lat': 39.26948102989272,
#      'lng': -85.83104992010728},
#     'southwest': {'lat': 39.26678137010728, 'lng': -85.83374957989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': '450 North Brewing Company',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1536,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113185567448141093303">Jeff Polk</a>'],
#     'photo_reference': 'ATtYBwKRASqnakCsIu8ltD2UnBBXbIEg-0I9jbToa5iOHCZwl-4ZuT4P2cPPaGM3Z0osYs2PCUojEvV2n8h8_J9exdfytKcippGAaNUVpURQWDSKRZrRIBAV1GP1UeQ7RucT_fgXyljreq4PshA3a6Rs0J8k6nTqFFdMdkesJIT9r3QYPegr',
#     'width': 2048}],
#   'place_id': 'ChIJPVkqwJQJa4gRPjxWFTraSnM',
#   'plus_code': {'compound_code': '7598+5W Columbus, Indiana',
#    'global_code': '86FP7598+5W'},
#   'rating': 4.4,
#   'reference': 'ChIJPVkqwJQJa4gRPjxWFTraSnM',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 465},
#  '47 Hills Brewing Co': {'business_status': 'OPERATIONAL',
#   'formatted_address': '137 S Linden Ave, South San Francisco, CA 94080, United States',
#   'geometry': {'location': {'lat': 37.6441833, 'lng': -122.4135194},
#    'viewport': {'northeast': {'lat': 37.64550277989272,
#      'lng': -122.4120260701073},
#     'southwest': {'lat': 37.64280312010728, 'lng': -122.4147257298928}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': '47 Hills Brewing Company',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3780,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106318455641608824513">Cody Gray</a>'],
#     'photo_reference': 'ATtYBwIcVvxZxwfAheDeixVrZHUzqt7GV_Ory6TYUEkjUhXbULhEij-4sYNbVMOwbk72l95khCAsbHwdljW12EXkkKFUTfKHjURkxMNq9qtPMR98shdt575Nqs5sy4T6RvmTRF_Sq-W0nd-RTLFP139bsYb2SmppFQuheWgy9Y0BNGzDoX87',
#     'width': 3024}],
#   'place_id': 'ChIJC3Qo77l5j4ARxakzfZ0HvRo',
#   'plus_code': {'compound_code': 'JHVP+MH South San Francisco, California',
#    'global_code': '849VJHVP+MH'},
#   'rating': 4.6,
#   'reference': 'ChIJC3Qo77l5j4ARxakzfZ0HvRo',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 174},
#  '49th State Brewing Anchorage': {'business_status': 'OPERATIONAL',
#   'formatted_address': '717 W 3rd Ave, Anchorage, AK 99501, United States',
#   'geometry': {'location': {'lat': 61.21962970000001, 'lng': -149.8959203},
#    'viewport': {'northeast': {'lat': 61.22093432989271,
#      'lng': -149.8945701701073},
#     'southwest': {'lat': 61.21823467010727, 'lng': -149.8972698298927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': '49th State Brewing - Anchorage',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 650,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105551501824474006144">49th State Brewing Co - Anchorage</a>'],
#     'photo_reference': 'ATtYBwLWy3Uez1nnMy32CbciYrd_-3lEgqOD8it-7QEjsGmLgx8_gW2bQzFUkXUz2PE2MDrT6ogWPIH1SyOky_-etkMqwQs9a_DadtiQGeiHoKiABjshXTl3080dGWptK6fOsa9yKY4GasZ1qEAr5YYoFlzSigh7KQPfmdQ_6GzER9ea9GX2',
#     'width': 872}],
#   'place_id': 'ChIJcRhn_Ya9yFYRAgyWbeaWyFI',
#   'plus_code': {'compound_code': '6493+VJ Point MacKenzie, Alaska',
#    'global_code': '93HG6493+VJ'},
#   'price_level': 2,
#   'rating': 4.5,
#   'reference': 'ChIJcRhn_Ya9yFYRAgyWbeaWyFI',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 4095},
#  '5 Lakes Brewing Co': {'business_status': 'OPERATIONAL',
#   'formatted_address': '1638 142nd Ave, Dorr, MI 49323, United States',
#   'geometry': {'location': {'lat': 42.7240779, 'lng': -85.7056013},
#    'viewport': {'northeast': {'lat': 42.72554932989272,
#      'lng': -85.70425332010727},
#     'southwest': {'lat': 42.72284967010727, 'lng': -85.7069529798927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': '5 Lakes Brewing Company',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114911131119075904321">Andy Steenbergen</a>'],
#     'photo_reference': 'ATtYBwJRovohpDWGNDQ2Qz9jfdMHECyxgQB9cSq1sf2AIQMDVZviL7tRGGfMubT8_hN8PYTKiNNZNZ4Iip2lGPFugjdnDpZYNtwsrVev_pQ7dxiNmvI2cjC-sH-hcZlwaPjmmHf0sbD-JDLCwYqRGd4FmK3wGbFTuW5w2A6WjoNr5hvaQxb5',
#     'width': 4032}],
#   'place_id': 'ChIJz2wo1j_JGYgRhCwbgswAmzw',
#   'plus_code': {'compound_code': 'P7FV+JQ Dorr, Michigan',
#    'global_code': '86JPP7FV+JQ'},
#   'price_level': 2,
#   'rating': 4.3,
#   'reference': 'ChIJz2wo1j_JGYgRhCwbgswAmzw',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 550},
#  '5280 Beer Company LLC Elevated Seltzer': {'business_status': 'OPERATIONAL',
#   'formatted_address': '5610 Yukon St, Arvada, CO 80002, United States',
#   'geometry': {'location': {'lat': 39.7995173, 'lng': -105.0823364},
#    'viewport': {'northeast': {'lat': 39.80086752989272,
#      'lng': -105.0811290701073},
#     'southwest': {'lat': 39.79816787010727, 'lng': -105.0838287298927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Elevated Seltzer',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3649,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108211324065770364407">A Google User</a>'],
#     'photo_reference': 'ATtYBwJsj9gKuXJ1CmJYGdI44dg2pdUgyN6uKXveiBsLn36dx_IffMiAmMoKmrgKWjAfaKbEzGV1_hJlWy8tuVuwP-op29QMR7GMttmeD7L8kayS9jI8ZseeFsCRrQc2BX3ZZPgxu7P3xJag0cHsCsrlXRj_bATGEve3u9kG6U01vqyAbtX5',
#     'width': 2949}],
#   'place_id': 'ChIJbRnTT72Ha4cRe1gR6SxGe20',
#   'plus_code': {'compound_code': 'QWX9+R3 Arvada, Colorado',
#    'global_code': '85FPQWX9+R3'},
#   'rating': 4.3,
#   'reference': 'ChIJbRnTT72Ha4cRe1gR6SxGe20',
#   'types': ['meal_delivery',
#    'meal_takeaway',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 44},
#  '6 Bears & A Goat Brewing Company LLC': {'business_status': 'OPERATIONAL',
#   'formatted_address': '1140 International Pkwy, Fredericksburg, VA 22406, United States',
#   'geometry': {'location': {'lat': 38.3624367, 'lng': -77.51422889999999},
#    'viewport': {'northeast': {'lat': 38.36372147989272,
#      'lng': -77.51247717010727},
#     'southwest': {'lat': 38.36102182010728, 'lng': -77.51517682989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': '6 Bears & A Goat Brewing Company',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116104097240694832871">Zack Flanagan</a>'],
#     'photo_reference': 'ATtYBwJiTc9p-mEfnT1v7h5hdG26ce5OPgSsLlc062aZd33eLfDsFFYPNZY8XnCIIM8G6LXURcdvV_GoMyW0B2Fpv7kMy-qNTznC_NTjCYtZ0dJjojQku69YQTgAoqz6o-vZ8_fgkpklkqgWDsyWoJctdeOOqdaSuBhxiY8EW1nwCQOz9Dv-',
#     'width': 4032}],
#   'place_id': 'ChIJFdDr8arrtokROPRXwNOpylg',
#   'plus_code': {'compound_code': '9F6P+X8 Fredericksburg, Virginia',
#    'global_code': '87C49F6P+X8'},
#   'rating': 4.4,
#   'reference': 'ChIJFdDr8arrtokROPRXwNOpylg',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 312},
#  '602 Brewing Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '919 Main St, Bastrop, TX 78602, United States',
#   'geometry': {'location': {'lat': 30.1099225, 'lng': -97.31987540000002},
#    'viewport': {'northeast': {'lat': 30.11127117989273,
#      'lng': -97.31857872010728},
#     'southwest': {'lat': 30.10857152010728, 'lng': -97.32127837989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': '602 Brewing Company',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 540,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117735802277423726269">A Google User</a>'],
#     'photo_reference': 'ATtYBwJEgAOv0aJwJpD74jA_w5zP5AlEEjD1DriRRy-HHGt5Yn-xfpm0lbkYCeoeGGRR5UKqpoFJCUCyZdMzegSbU2aJB64UGIG9MnpZgMyKP-8wDpVrHaKXwUdrSUwifOSXK2HpDic1fXk7CO2DxN26la3ZGLrl_Om81EDan3UQNl5vjM_T',
#     'width': 720}],
#   'place_id': 'ChIJkXGesUSaRIYRYuTWrq7szQ0',
#   'plus_code': {'compound_code': '4M5J+X2 Bastrop, Texas',
#    'global_code': '86244M5J+X2'},
#   'price_level': 2,
#   'rating': 4.3,
#   'reference': 'ChIJkXGesUSaRIYRYuTWrq7szQ0',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 287},
#  '608 Brewing Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '83 Copeland Ave, La Crosse, WI 54603, United States',
#   'geometry': {'location': {'lat': 43.8258353, 'lng': -91.24988979999999},
#    'viewport': {'northeast': {'lat': 43.82717557989272,
#      'lng': -91.24826077010728},
#     'southwest': {'lat': 43.82447592010728, 'lng': -91.25096042989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': '608 Brewing Company',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3036,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103518138679806821841">Ben Fyvie</a>'],
#     'photo_reference': 'ATtYBwICpiJ7VGhTffdBVEnyGciuU3zyXS824Wwi84Ot4mXLOOU4jyrjrfuzme6FV-hfgtw_hNcXy7vfmnVErmHuaf9x0ug2-Ra6TE5YQ42OvXJfVKXZzFNeAj5PFS1iS-sorvPsY3rr6xYKJwaqsGjI_xZJSjBHMJbTCtMyJW9advngSXsF',
#     'width': 4048}],
#   'place_id': 'ChIJe0slaP9U-YcRv96Sx7C4KTw',
#   'plus_code': {'compound_code': 'RQG2+82 La Crosse, Wisconsin',
#    'global_code': '86MCRQG2+82'},
#   'rating': 4.7,
#   'reference': 'ChIJe0slaP9U-YcRv96Sx7C4KTw',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 158},
#  '7 Dogs Brewpub': {'business_status': 'OPERATIONAL',
#   'formatted_address': '360 W Spring St, Wytheville, VA 24382, United States',
#   'geometry': {'location': {'lat': 36.9475853, 'lng': -81.0850021},
#    'viewport': {'northeast': {'lat': 36.94888687989272,
#      'lng': -81.08359517010727},
#     'southwest': {'lat': 36.94618722010728, 'lng': -81.08629482989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': '7 Dogs Brew Pub',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2327,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104123621741005846895">Ian Kerr</a>'],
#     'photo_reference': 'ATtYBwKCDYqnbAe8phvcILDAGWhijC8vkqI81Ys1kddlz-ImD43GDEWS3Nb8hf58_FnDvAHqAD-H7JJ63Dy7I8E3jq5tepkStWXSSQFk7eioM9lhgayJgq7Hr94TBm_zak374ODpjwGZQmxqqZ_c4myl-lxjQh2ftTEWBFaSeHhqv5pl5zkM',
#     'width': 3344}],
#   'place_id': 'ChIJZ3_zCCThUYgRQSUZNfGexyQ',
#   'plus_code': {'compound_code': 'WWX7+2X Wytheville, Virginia',
#    'global_code': '868WWWX7+2X'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJZ3_zCCThUYgRQSUZNfGexyQ',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 406},
#  '7 Hermits Brewing Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '1020 Capitol St, Eagle, CO 81631, United States',
#   'geometry': {'location': {'lat': 39.6413327, 'lng': -106.8308052},
#    'viewport': {'northeast': {'lat': 39.64268192989272,
#      'lng': -106.8295591701073},
#     'southwest': {'lat': 39.63998227010728, 'lng': -106.8322588298927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': '7 Hermits Brewing Company',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1536,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104435915771039249335">7 Hermits Brewing Company</a>'],
#     'photo_reference': 'ATtYBwK4So7xFQ4u5u4s2M6n8QVSZ6bXCnj3BA1NAbh7d5wA_EU0lL0xwwDg663YXp2Ra0b0RT6FRJfGL1gFhSfmqfRGq9NWllpACcEXBuz04FlgOUrt9L_HVQ_1W-RV18Co_7P3L2ihVEwBRnGbozg-2xF3j53XaxRqrSKINCJDfSHcu7zj',
#     'width': 2048}],
#   'place_id': 'ChIJ-0i00LLGQYcRIhkD4OMNrdk',
#   'plus_code': {'compound_code': 'J5R9+GM Eagle, Colorado',
#    'global_code': '85FMJ5R9+GM'},
#   'rating': 4,
#   'reference': 'ChIJ-0i00LLGQYcRIhkD4OMNrdk',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 79},
#  '7 Hills Brewing Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '1085 Washington St, Dubuque, IA 52001, United States',
#   'geometry': {'location': {'lat': 42.504616, 'lng': -90.663603},
#    'viewport': {'northeast': {'lat': 42.50599237989272,
#      'lng': -90.66216077010728},
#     'southwest': {'lat': 42.50329272010728, 'lng': -90.66486042989271}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': '7 Hills Brewing Company',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 932,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101868311229982357417">A Google User</a>'],
#     'photo_reference': 'ATtYBwLNrj3BYrCEpmceo9vuTAnQKrN_TCZ1yWzzqalaNsIlmL_WXAcQmcfFhf7woNzSpas6wKFR3LenqtI5NKQ835qidwB3HKrkWVBPT_diwD4LRPFA4JcvPzq3kkFnymi1zAL0r3ZVLd1AkOhHpksgU5KnIztDDkW1tW15YS5zb8W2otqd',
#     'width': 1656}],
#   'place_id': 'ChIJix9b-Zsr44cRhZgPsJOQ4ys',
#   'plus_code': {'compound_code': 'G83P+RH Dubuque, Iowa',
#    'global_code': '86JFG83P+RH'},
#   'price_level': 2,
#   'rating': 4.5,
#   'reference': 'ChIJix9b-Zsr44cRhZgPsJOQ4ys',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 882},
#  '8 Bit Brewing Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '26755 Jefferson Ave, Murrieta, CA 92562, United States',
#   'geometry': {'location': {'lat': 33.5297174, 'lng': -117.1761469},
#    'viewport': {'northeast': {'lat': 33.53131052989272,
#      'lng': -117.1748568701073},
#     'southwest': {'lat': 33.52861087010728, 'lng': -117.1775565298927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': '8 bit Brewing Company',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1152,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109562610448926339782">A Google User</a>'],
#     'photo_reference': 'ATtYBwLl1SzEtF-cJdHq5KzTKtDUmoNhqKjaTYuJptMHLplMUC56YeDTkGr_LmBgHyhPVzbz5ex6FWpjf9ay86wZCwncvyp0F_1YJX1HtGlc839rztwOIKE_mqbB1p0lVIS5MRJn3dFn5q4i76lAbJ5QiOlwQFDijNdXHV_ZuSxLwH1969FQ',
#     'width': 2048}],
#   'place_id': 'ChIJYYXKsuOB3IARlcaySTCt-S8',
#   'plus_code': {'compound_code': 'GRHF+VG Murrieta, California',
#    'global_code': '8554GRHF+VG'},
#   'price_level': 2,
#   'rating': 4.7,
#   'reference': 'ChIJYYXKsuOB3IARlcaySTCt-S8',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 555},
#  '841 Brewhouse': {'business_status': 'OPERATIONAL',
#   'formatted_address': '841 E Milwaukee St, Whitewater, WI 53190, United States',
#   'geometry': {'location': {'lat': 42.8320611, 'lng': -88.7138878},
#    'viewport': {'northeast': {'lat': 42.83353892989272,
#      'lng': -88.71249117010728},
#     'southwest': {'lat': 42.83083927010728, 'lng': -88.71519082989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': '841 Brewhouse',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 518,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107582602694508363398">A Google User</a>'],
#     'photo_reference': 'ATtYBwLxuCumN-YrQKWG_SfK2UA5p30Q9eb8Q6RslXRM05ykAbXAqwhoyWSrwGXTpdgdCrhPwuavrb4T0g2lSdFPFTTE5k8qEP-0s752t0dH71e5G73hORt0vtUFhTECYH4SEIASZXQMEeUcXi3_fP_qf4Zt0yYSp24alzl-j1FMIomhTRfD',
#     'width': 339}],
#   'place_id': 'ChIJ38Yid8zgBYgRsebbxCWzvuI',
#   'plus_code': {'compound_code': 'R7JP+RC Whitewater, Wisconsin',
#    'global_code': '86JHR7JP+RC'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJ38Yid8zgBYgRsebbxCWzvuI',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 620},
#  '903 Brewers': {'business_status': 'OPERATIONAL',
#   'formatted_address': '1718 S Elm St, Sherman, TX 75090, United States',
#   'geometry': {'location': {'lat': 33.6172681, 'lng': -96.60702979999999},
#    'viewport': {'northeast': {'lat': 33.61864242989273,
#      'lng': -96.60554692010729},
#     'southwest': {'lat': 33.61594277010728, 'lng': -96.60824657989274}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': '903 Brewers',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 457,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111802576425019717452">A Google User</a>'],
#     'photo_reference': 'ATtYBwLmeiZ64Q2BdtwwGO1WhIVNvlgBDvKhsGUqnMjaj5nM_IlbwX1qxEgKduj0khbigJAqHGSpz7bFWGU6lEAO7FGQOILg3C2wRUrs48_TaB-1b34xqQM-CuTVWTT7QzskzHqhowip9Ft2DKFP7DmEkwPv3_48KAGTcBsG-b_4ZQKa-SCC',
#     'width': 1024}],
#   'place_id': 'ChIJAcxKsJ1iTIYRojBEa1GyFZI',
#   'plus_code': {'compound_code': 'J98V+W5 Sherman, Texas',
#    'global_code': '8655J98V+W5'},
#   'rating': 4.6,
#   'reference': 'ChIJAcxKsJ1iTIYRojBEa1GyFZI',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 155},
#  'ALULU Brew Pub': {'business_status': 'OPERATIONAL',
#   'formatted_address': '2011 S Laflin St, Chicago, IL 60608, United States',
#   'geometry': {'location': {'lat': 41.854733, 'lng': -87.663403},
#    'viewport': {'northeast': {'lat': 41.85606057989271,
#      'lng': -87.66220972010727},
#     'southwest': {'lat': 41.85336092010727, 'lng': -87.66490937989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Alulu Brewery and Pub',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101500287084040117443">Serge Lubomudrov</a>'],
#     'photo_reference': 'ATtYBwJ4PTBkUSEPAzUfxi8Jmxi70hmVUz_6jNOxL0te2_8qm88x6qWaNSx1kRccOsdoGmWve3wjfO_TAkCodcaZ6hZ4gLLkBqVrLcxMdb6Tm8k4AlAgrhanMX2SCWg1IA2qKmtrVyNBMugD9BbgWTjiPBoRo63JOFcQcSQjDnhiZArXpoA',
#     'width': 3024}],
#   'place_id': 'ChIJY1EajKktDogRGAw87A-S9NQ',
#   'plus_code': {'compound_code': 'V83P+VJ Chicago, Illinois',
#    'global_code': '86HJV83P+VJ'},
#   'price_level': 1,
#   'rating': 4.5,
#   'reference': 'ChIJY1EajKktDogRGAw87A-S9NQ',
#   'types': ['bar', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 300},
#  'Aberrant Ales': {'business_status': 'OPERATIONAL',
#   'formatted_address': '219 W Grand River Ave, Howell, MI 48843, United States',
#   'geometry': {'location': {'lat': 42.6076332, 'lng': -83.9314247},
#    'viewport': {'northeast': {'lat': 42.60905407989272,
#      'lng': -83.93002637010727},
#     'southwest': {'lat': 42.60635442010727, 'lng': -83.93272602989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Aberrant Ales',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1536,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108333463592138112321">A Google User</a>'],
#     'photo_reference': 'ATtYBwJW30YbbzJIkK_pNk2goH_tTT60nFWQN5wPl1KqVb3un8cUYlYhegZJWIBT5SBx5PS_wXnt7yQjZtfWn_RRaUVAgk5vRJFUCzoK45ij3TYlc6-AgFJUdu-8bVrqUn45reWgsjJ41G8CApOkWIK5jHlw5s7kZP4DP-JCZg-yEHfvf3rM',
#     'width': 2048}],
#   'place_id': 'ChIJ_U98j19HI4gRkfoTPCXc6KI',
#   'plus_code': {'compound_code': 'J359+3C Howell, Michigan',
#    'global_code': '86JRJ359+3C'},
#   'rating': 4.3,
# ...
#   'name': 'Knotty Pine Brewing',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115395026598950933835">Kurtis Shafer</a>'],
#     'photo_reference': 'ATtYBwKYCk3PqTy_4dntY_dPNJcGwpuYo-So32FrYdEE07ttKGz2d23Zvu_TZ6-vpdrprTYTRNlDs5PSmbSgWw8nXWkV2XDv4sd5J9DXFJ8Ra9d588qdRk-YFdXbzZytnq2oQAlwumkazya7CFZF2dOa5T6xL_ssJTQaGrhjaGuPK4j2oMcz',
#     'width': 4032}],
#   'place_id': 'ChIJfyDoL0mOOIgRUTXzldu1Qt4',
#   'plus_code': {'compound_code': 'XWPW+4R Columbus, Ohio',
#    'global_code': '86FRXWPW+4R'},
#   'price_level': 2,
#   'rating': 4.3,
#   'reference': 'ChIJfyDoL0mOOIgRUTXzldu1Qt4',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 297},
#  'Knox County Brewing Co': {'business_status': 'OPERATIONAL',
#   'formatted_address': '2900 W Main St, Galesburg, IL 61401, United States',
#   'geometry': {'location': {'lat': 40.9467849, 'lng': -90.4186172},
#    'viewport': {'northeast': {'lat': 40.94848477989272,
#      'lng': -90.41710552010728},
#     'southwest': {'lat': 40.94578512010727, 'lng': -90.41980517989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'name': 'Knox County Brewing Co | Drink Good Beer. Do Good Work.',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108381437560882781868">A Google User</a>'],
#     'photo_reference': 'ATtYBwLmuXVDhg_8IasR47FrK0WqQYteCtK1YQmLgdav_zZl-taIlZP8jPkLy3SyA_euOdR0tyPRwIvJS6YxIwpBgWaFhKm0rUr6wQ0pqBKJp8Z4HcZ9LgfSmRzKQ-xAKGbjxysYlOPaJsYdFcwg-KbiXkkcSmD2FloFUet7BUlv-q7SMPGy',
#     'width': 3024}],
#   'place_id': 'ChIJn_GEypO94YcR1TaNPT617OQ',
#   'plus_code': {'compound_code': 'WHWJ+PH Galesburg, Illinois',
#    'global_code': '86GFWHWJ+PH'},
#   'rating': 4.9,
#   'reference': 'ChIJn_GEypO94YcR1TaNPT617OQ',
#   'types': ['food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 29},
#  'Knucklehead Craft Brewing': {'business_status': 'OPERATIONAL',
#   'formatted_address': '426 Ridge Rd, Webster, NY 14580, United States',
#   'geometry': {'location': {'lat': 43.20598330000001, 'lng': -77.5121806},
#    'viewport': {'northeast': {'lat': 43.20724147989272,
#      'lng': -77.51087117010728},
#     'southwest': {'lat': 43.20454182010728, 'lng': -77.51357082989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Knucklehead Craft Brewing',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 750,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117652566595030340800">Knucklehead Craft Brewing</a>'],
#     'photo_reference': 'ATtYBwJXzuIV6KcLWxH6Q5WhQRom-oMw9Y5aa9iLeGtRZ0BxuE4Qy4tBMTJmUj5019Km9yVjP3vedWEFnr1uyQGe8QFBKwfEj5j7qrZeUcSjw_KyDsBDbn-fppqwocBpKFflgKWSzHKyYWTtINC6Xc4v4KhCzeTM80jnlCvdrzjbHjgZAMkA',
#     'width': 1000}],
#   'place_id': 'ChIJL-8N2QvJ1okRZGN2R5iGaCw',
#   'plus_code': {'compound_code': '6F4Q+94 Webster, New York',
#    'global_code': '87M46F4Q+94'},
#   'price_level': 2,
#   'rating': 4.7,
#   'reference': 'ChIJL-8N2QvJ1okRZGN2R5iGaCw',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 572},
#  'Knuth Brewing Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '221 Watson St, Ripon, WI 54971, United States',
#   'geometry': {'location': {'lat': 43.8445925, 'lng': -88.83872649999999},
#    'viewport': {'northeast': {'lat': 43.84594207989272,
#      'lng': -88.83738592010728},
#     'southwest': {'lat': 43.84324242010727, 'lng': -88.84008557989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Knuth Brewing Company',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3456,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105416528271149387737">Fat Bruce&#39;s Bakery and Eating Kitchen and Knuth Brewing Company</a>'],
#     'photo_reference': 'ATtYBwK62b5wcr9RBFXFg565Sai8xB2La5p0z1-iD0musjfg7SOMZ9Nvw3olx5SDzJ7h4JdMwR3hhH7SLNsReu7PugbCQXwx6vKbWgucnsJ6H65UCAKNwoc_t5uVDwp1hy2bLrssHBri-7HL5rn5NLXihcX7FBSJ98LKF-5V0vIFqfwu6taV',
#     'width': 5184}],
#   'place_id': 'ChIJmf7g_ThUAYgRv0TJD1_siSc',
#   'plus_code': {'compound_code': 'R5V6+RG Ripon, Wisconsin',
#    'global_code': '86MHR5V6+RG'},
#   'price_level': 2,
#   'rating': 4.7,
#   'reference': 'ChIJmf7g_ThUAYgRv0TJD1_siSc',
#   'types': ['bakery',
#    'cafe',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 588},
#  'Kobold Brewing': {'business_status': 'OPERATIONAL',
#   'formatted_address': '245 SW 6th St, Redmond, OR 97756, United States',
#   'geometry': {'location': {'lat': 44.2747222, 'lng': -121.1744444},
#    'viewport': {'northeast': {'lat': 44.27608947989271,
#      'lng': -121.1730132701073},
#     'southwest': {'lat': 44.27338982010727, 'lng': -121.1757129298927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Kobold Brewing /The Vault Taphouse',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 516,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104890333053498487267">A Google User</a>'],
#     'photo_reference': 'ATtYBwLg6PW_UQGSmXVu-6YCHioqXH5TGKxe79GYVcCpq7HWuvVueQk67yCWDQGLY35k2X142N1jw66kD7lFMEfPMsg-gEtgaSOCkqOCBzI-fuLzwJh3ZpcNWC89swlE85Rs0jtD6_0Ym3FBCPjwywH3NAbfMhvUKrWZeu1bejj3NdEVtYvU',
#     'width': 915}],
#   'place_id': 'ChIJNaNoydsqv1QRIdhVgJDdxIw',
#   'plus_code': {'compound_code': '7RFG+V6 Redmond, Oregon',
#    'global_code': '84PW7RFG+V6'},
#   'price_level': 1,
#   'rating': 4.7,
#   'reference': 'ChIJNaNoydsqv1QRIdhVgJDdxIw',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 254},
#  'Kokopelli Beer Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '8931 N Harlan St, Westminster, CO 80031, United States',
#   'geometry': {'location': {'lat': 39.8584612, 'lng': -105.0652049},
#    'viewport': {'northeast': {'lat': 39.85980937989272,
#      'lng': -105.0637450701073},
#     'southwest': {'lat': 39.85710972010727, 'lng': -105.0664447298927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Kokopelli Beer Company',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106365601837874082046">Soham Gore</a>'],
#     'photo_reference': 'ATtYBwKb0Sm8aXC9ajJJEKZLRpJpcS_tKyHL2PhD4Gj8K4fKNzcKVa1_fXLI0Pk58NpAx8UkY8RjhfX2xz3EVnru37Jf8tstxFgVDTFw9bm6IN16-IHtZFC-gpZd-ve-6SHBR0CHtAPpoOQ2nfg18dMv4QoitoRyqnXvW5vnZNK5EOpVHbs',
#     'width': 4032}],
#   'place_id': 'ChIJ2VXQkbCJa4cRbUbsbKALsIM',
#   'plus_code': {'compound_code': 'VW5M+9W Westminster, Colorado',
#    'global_code': '85FPVW5M+9W'},
#   'price_level': 2,
#   'rating': 4.6,
#   'reference': 'ChIJ2VXQkbCJa4cRbUbsbKALsIM',
#   'types': ['meal_delivery',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 679},
#  'Kootenai River Brewing Co': {'business_status': 'OPERATIONAL',
#   'formatted_address': '6424 Riverside St, Bonners Ferry, ID 83805, United States',
#   'geometry': {'location': {'lat': 48.6977157, 'lng': -116.3132248},
#    'viewport': {'northeast': {'lat': 48.69912792989272,
#      'lng': -116.3118857701073},
#     'southwest': {'lat': 48.69642827010728, 'lng': -116.3145854298927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Kootenai River Brewing Co',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3936,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110018056230844246714">Obregon Construction</a>'],
#     'photo_reference': 'ATtYBwKGQzCseWgXrSetBoHS3lbVfFbcoC2Cffm9_-75vQW8HsiZziJBjiZ7sqYPGlMYwEIYpa3YOk5EwXcOpZMYAHP37tJMBBIYh2JgoyoQb7xeh55ezF0HPKjVBGhEASlHLiq20Dj9YEJxb4vEM7ms5RgAjLy4xjmh8wOz30uQIj0oTUCA',
#     'width': 5248}],
#   'place_id': 'ChIJ6TZt1AKOY1MRvYEomt6a1bg',
#   'plus_code': {'compound_code': 'MMXP+3P Bonners Ferry, Idaho',
#    'global_code': '85W5MMXP+3P'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJ6TZt1AKOY1MRvYEomt6a1bg',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 383},
#  'Kopacetic Beer Factory': {'business_status': 'OPERATIONAL',
#   'formatted_address': '12195 US-421, Monticello, IN 47960, United States',
#   'geometry': {'location': {'lat': 40.7264302, 'lng': -86.7546821},
#    'viewport': {'northeast': {'lat': 40.72760012989272,
#      'lng': -86.75344577010728},
#     'southwest': {'lat': 40.72490047010728, 'lng': -86.75614542989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'name': 'Kopacetic Beer Factory',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112685313783194381257">A Google User</a>'],
#     'photo_reference': 'ATtYBwILs1dwcsws9X_skSw8LyXbd8YclSWNFkVzevxqMq0aRnn3kxWxguviEKY_K-EeYLkZBir2QaZylSlU7kA0n_BHW8GHTV_03JkPPlpBlknWuW4gCN4zIYRyq7JHFZ5hlVnzabc0OWWU4xKBXYWNquDFxLSfKwbbdP9SrKP6PIGarUTL',
#     'width': 3024}],
#   'place_id': 'ChIJpXIuLZKvE4gR3NCfn3Wo2V8',
#   'plus_code': {'compound_code': 'P6GW+H4 Monticello, Indiana',
#    'global_code': '86GMP6GW+H4'},
#   'rating': 4.6,
#   'reference': 'ChIJpXIuLZKvE4gR3NCfn3Wo2V8',
#   'types': ['liquor_store',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 97},
#  'Koto Brewing': {'business_status': 'OPERATIONAL',
#   'formatted_address': '156 Main Ave W, Twin Falls, ID 83301, United States',
#   'geometry': {'location': {'lat': 42.556765, 'lng': -114.4707481},
#    'viewport': {'northeast': {'lat': 42.55801052989273,
#      'lng': -114.4695393701073},
#     'southwest': {'lat': 42.55531087010728, 'lng': -114.4722390298927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Koto Brewing Co.',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108707223782711219647">Gary May</a>'],
#     'photo_reference': 'ATtYBwJE4EYHAAe_dOsLiAc_b-FGy5Knuf7U0p8TIOBbs60GEItDO2joPJKhKKHzFOJCNWn8lNFNwjWPEo4oVHY4OjmyYp-wJo_DEkqRz3Xd27PSfGCWYrm66AzvM7glI8VcStn3fUECHwkiXc84nrsaebePbZ5W1eh4Z66RYa4A34SCyR84',
#     'width': 4032}],
#   'place_id': 'ChIJJxIe-KajrFQRCdfmIQSaxFU',
#   'plus_code': {'compound_code': 'HG4H+PP Twin Falls, Idaho',
#    'global_code': '85J7HG4H+PP'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJJxIe-KajrFQRCdfmIQSaxFU',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 647},
#  'Kozy Yak Brewery & Fresar Winery': {'business_status': 'OPERATIONAL',
#   'formatted_address': '197 N Main St, Rosholt, WI 54473, United States',
#   'geometry': {'location': {'lat': 44.6293158, 'lng': -89.3093877},
#    'viewport': {'northeast': {'lat': 44.63068307989272,
#      'lng': -89.30786987010728},
#     'southwest': {'lat': 44.62798342010727, 'lng': -89.31056952989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Kozy Yak Brewery & Winery',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3936,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111377254856665436957">Deana Hamel</a>'],
#     'photo_reference': 'ATtYBwJMDie3vJWBIs1IlVJHgn1houskMUcp3Rxy_cTuVRFlLV5fUpS4-xrDFFpt5pTJQ_VgQ4OvD1-O437kc6viyh6qFz20_f5nw39lwZnnuMPy24AtRhVZgem2C4xtavm2yihalDMQjlY3xhonvEvu6-1v-PEKnb5kH_-GW9XquyntXHIA',
#     'width': 5248}],
#   'place_id': 'ChIJM0peOLG2AYgRzTMEzV6Meio',
#   'plus_code': {'compound_code': 'JMHR+P6 Rosholt, Wisconsin',
#    'global_code': '86PGJMHR+P6'},
#   'price_level': 1,
#   'rating': 4.6,
#   'reference': 'ChIJM0peOLG2AYgRzTMEzV6Meio',
#   'types': ['bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 19},
#  'Krafty Draft Brew Pub': {'business_status': 'OPERATIONAL',
#   'formatted_address': '269 Charter Oak Road, Lexington, SC 29072, United States',
#   'geometry': {'location': {'lat': 33.9878719, 'lng': -81.3056443},
#    'viewport': {'northeast': {'lat': 33.98915092989272,
#      'lng': -81.30431492010729},
#     'southwest': {'lat': 33.98645127010727, 'lng': -81.30701457989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Krafty Draft Brew Pub LLC',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3826,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101612482055037829830">Krafty Draft Brew Pub LLC</a>'],
#     'photo_reference': 'ATtYBwKvKDg42qMwuO_njgObWeczNL1oeA-NPU59WP6QIO9nwtDqqhQjQCgZElHJRRWm1_eQ2EC8YYumziB82TsaC_w6tJXhbiwH3dmqZjgUzI1psImSClMArnYWfb1lxiC4s00a2SJe-f61fuX_EacO3CUMSIsqLRja1IQJceIvrI3-gg-A',
#     'width': 5739}],
#   'place_id': 'ChIJR_PMUVCQ-IgRF276mfVK-58',
#   'plus_code': {'compound_code': 'XMQV+4P Lexington, South Carolina',
#    'global_code': '865WXMQV+4P'},
#   'price_level': 2,
#   'rating': 4.6,
#   'reference': 'ChIJR_PMUVCQ-IgRF276mfVK-58',
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 459},
#  "Krogh's Restaurant and Brewpub": {'business_status': 'OPERATIONAL',
#   'formatted_address': '23 White Deer Plaza, Sparta, NJ 07871, United States',
#   'geometry': {'location': {'lat': 41.031071, 'lng': -74.6403177},
#    'viewport': {'northeast': {'lat': 41.03242577989271,
#      'lng': -74.63906992010727},
#     'southwest': {'lat': 41.02972612010727, 'lng': -74.64176957989272}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': "Krogh's Restaurant & Brew Pub",
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 278,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101036809513937207357">Krogh&#39;s Restaurant &amp; Brew Pub</a>'],
#     'photo_reference': 'ATtYBwKeoTjBzdGesuLDttci8NeXqv3TsKKl8jJ-tSiU6mvmdpQ-9V1NBXGdof2HfnwKdIG7dtnkS-RykI1OryeLGP1cLzJ3t765jxsThimbwdU9PnaogBJ73Kx97N77V9xYWDC8GwurCQEPGNLEqP-GEcfxVq0--hDyv8hdN22sJCIK7E_o',
#     'width': 400}],
#   'place_id': 'ChIJBfZimmJyw4kRJF81fjbO2GU',
#   'plus_code': {'compound_code': '29J5+CV Sparta, New Jersey',
#    'global_code': '87H729J5+CV'},
#   'price_level': 2,
#   'rating': 4.5,
#   'reference': 'ChIJBfZimmJyw4kRJF81fjbO2GU',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 336},
#  'Krootz Brewing Company': {'business_status': 'OPERATIONAL',
#   'formatted_address': '315 W Elm St, Gainesville, TX 76240, United States',
#   'geometry': {'location': {'lat': 33.6252022, 'lng': -97.1476327},
#    'viewport': {'northeast': {'lat': 33.62645622989272,
#      'lng': -97.14628512010728},
#     'southwest': {'lat': 33.62375657010728, 'lng': -97.14898477989273}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'name': 'Krootz Brewing Company',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101427652420931504307">A Google User</a>'],
#     'photo_reference': 'ATtYBwKINJjuFiYrs1w4lmfrh3fPO-aaT5l9SRW5n9CmLWqZZsjREIXj3NtiOUnA_eAPRGIFlemM5qkrAZNDfCGeZ5S_g-JVXDPKOnh2bwR2OOUZ4RgokEtGIn-5O6oa4PFAjmBJ775D6irPWP1tYhCce5ysIa-RvnagLnS3TS_jIbo1vZ8Z',
#     'width': 4032}],
#   'place_id': 'ChIJn2UKiZEBTYYR2mNoIBQWV0c',
#   'plus_code': {'compound_code': 'JVG2+3W Gainesville, Texas',
#    'global_code': '8654JVG2+3W'},
#   'rating': 4.8,
#   'reference': 'ChIJn2UKiZEBTYYR2mNoIBQWV0c',
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 111},
#  ...}

# %%
names = list()
names_original =list()
location = list()
rating = list()
total = list()

for each in full:
    
    #If the value of a query is just an empty list,
    #record the data as null
    if type(full[each]) is list:
        names.append(each)
        names_original.append('N/A')
        location.append('N/A')
        rating.append('N/A')
        total.append('N/A')
    #Else, append each key of ineterest into a list that will be converted into
    #a DataFrame column
    else:
        names.append(each)
        names_original.append(full[each]['name'])
        location.append(full[each]['geometry']['location'])

        #Some of Google Places json data did not contain a average raing 
        #or total user ratings, so I wrote a try and except to catch the error 
        #and add the respective keys with the corresponding value
        try:
            rating.append(full[each]['rating'])
            
        except:
            full[each]['rating'] = 'N/A'
            rating.append(full[each]['rating'])
         
        try:
            total.append(full[each]['user_ratings_total'])
        except:
            full[each]['user_ratings_total'] = 'N/A'
            total.append(full[each]['user_ratings_total'])
            
final = pd.DataFrame()

final['location_name'] = names
final['google_name'] = names_original
final['Location'] = location
final['Average User Rating'] = rating
final['Total User Rating'] = total

# %%
#Sort the names and reset the indexes
final = final.sort_values('Master List Query')
final = final.reset_index()
final = final.drop(columns='index')
final

# %%
final.to_csv('/content/drive/MyDrive/Stuff For Project Wynton/full_table.csv')

# %% [markdown]
# ## Experimentation (cleaning/conversion)

# %%
#This is my attempt to simply pull the names and ratings from the list
#The resulting data frame

fulltable = pd.DataFrame()

fulltable['Brewery'] = names
fulltable['Address'] = rating
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-d846b4839781> in <module>()
#       2
#       3 fulltable['Brewery'] = names
# ----> 4 fulltable['Address'] = rating
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3042         else:
#    3043             # set column
# -> 3044             self._set_item(key, value)
#    3045
#    3046     def _setitem_slice(self, key: slice, value):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3118         """
#    3119         self._ensure_valid_index(value)
# -> 3120         value = self._sanitize_column(key, value)
#    3121         NDFrame._set_item(self, key, value)
#    3122
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3766
#    3767             # turn me into an ndarray
# -> 3768             value = sanitize_index(value, self.index)
#    3769             if not isinstance(value, (np.ndarray, Index)):
#    3770                 if isinstance(value, list) and len(value) > 0:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/construction.py in sanitize_index(data, index)
#     746     if len(data) != len(index):
#     747         raise ValueError(
# --> 748             "Length of values "
#     749             f"({len(data)}) "
#     750             "does not match length of index "
#
# ValueError: Length of values (13235) does not match length of index (7794)

# %%
fulltable
# Out:
#                           Brewery
# 0                     101 Brewery
# 1             122 West Brewing Co
# 2                12Degree Brewing
# 3                15 24 Brew House
# 4                16 Stone Brewpub
# ...                           ...
# 7789                      ZumBier
# 7790  Zuni Street Brewing Company
# 7791              Zwei Brewing Co
# 7792      Zymurcracy Beer Company
# 7793           Zymurgy Brewing Co
#
# [7794 rows x 1 columns]
